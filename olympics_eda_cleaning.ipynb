# %% [markdown]
# # Exploring, cleaning, aggregating olympics results
# Aim is to have an aggregated table of countries' olympic results per year (i.e. each row is a country-year, with columns for medals (gsb and total)
#
# Results data sourced from Kaggle and seems a bit crap in some places. Could scrape from the IOC site if more serious analysis needed.
#
# **The trouble with this data is that the teams and athlete names require lots of work to clean, so investigating other datasets instead (e.g. scraping results myself from reference sites)**
#
# ### To Do
# - flag stripped medals
# - Generate data (and model) for medals per event per country per year

# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz
import os

# %%
path = r'C:\Users\tmais\Documents\Coding\Python\Projects\ML\OlympicsResults'
results_file = r'athlete_events.csv'

results_raw = pd.read_csv(os.path.join(path,results_file))
results_raw.head(7)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer       London           Judo
# 2  DEN  1920 Summer  1920  Summer    Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
#
#                                 Event Medal
# 0         Basketball Men's Basketball   NaN
# 1        Judo Men's Extra-Lightweight   NaN
# 2             Football Men's Football   NaN
# 3         Tug-Of-War Men's Tug-Of-War  Gold
# 4    Speed Skating Women's 500 metres   NaN
# 5  Speed Skating Women's 1,000 metres   NaN
# 6    Speed Skating Women's 500 metres   NaN

# %% [markdown]
# Each row is an individual athlete competing in an event (but it only has results for gsb)
# Note that ID is a unique identifier for each individual athlete--helpful for when multiple athletes share the same name.

# %%
results = results_raw.reset_index()
results['games_name'] = results.apply(lambda row: '{} {}'.format(row.City, row.Year),axis=1)
results['summer'] = 0
results.loc[results.Season=='Summer', 'summer'] = 1
results.head()
# Out:
#    index  ID                      Name Sex   Age  Height  Weight  \
# 0      0   1                 A Dijiang   M  24.0   180.0    80.0
# 1      1   2                  A Lamusi   M  23.0   170.0    60.0
# 2      2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3      3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4      4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
#
#              Team  NOC        Games  Year  Season       City          Sport  \
# 0           China  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1           China  CHN  2012 Summer  2012  Summer     London           Judo
# 2         Denmark  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4     Netherlands  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal      games_name  summer
# 0       Basketball Men's Basketball   NaN  Barcelona 1992       1
# 1      Judo Men's Extra-Lightweight   NaN     London 2012       1
# 2           Football Men's Football   NaN  Antwerpen 1920       1
# 3       Tug-Of-War Men's Tug-Of-War  Gold      Paris 1900       1
# 4  Speed Skating Women's 500 metres   NaN    Calgary 1988       0

# %%
results.NOC.value_counts().head(20).plot(kind='barh', title='Top 20 countries by athlete-event count')
# Out:
# <AxesSubplot:title={'center':'Top 20 countries by athlete-event count'}>

# %%
results.Event.value_counts().head(20).plot(kind='barh', title='Top 20 events by athlete-count')
# Out:
# <AxesSubplot:title={'center':'Top 20 events by athlete-count'}>

# %%
results.groupby('Games').count().tail(10)['ID'].plot(kind='barh', title='Participant counts for 10 games back from 2016 inclusive')
# Out:
# <AxesSubplot:title={'center':'Participant counts for 10 games back from 2016 inclusive'}, ylabel='Games'>

# %% [markdown]
# ## Get list of participant teams per Olympic games

# %%
games_teams = results.groupby(['games_name', 'Team'])[['summer', 'Year']].first().sort_values('Year').reset_index()
games_teams.head()
# Out:
#     games_name                           Team  summer  Year
# 0  Athina 1896                      Australia       1  1896
# 1  Athina 1896        Australia/Great Britain       1  1896
# 2  Athina 1896                        Austria       1  1896
# 3  Athina 1896                        Denmark       1  1896
# 4  Athina 1896  Ethnikos Gymnastikos Syllogos       1  1896

# %%
games_team_count = games_teams.groupby('games_name')['Team'].count().reset_index().rename(columns={'Team': 'n_teams'})
games = games_teams.groupby('games_name')[['summer', 'Year']].first().sort_values('Year').reset_index()
games = games.merge(games_team_count, how='left', on='games_name')
games.head()
# Out:
#        games_name  summer  Year  n_teams
# 0     Athina 1896       1  1896       18
# 1      Paris 1900       1  1900      190
# 2  St. Louis 1904       1  1904       79
# 3     Athina 1906       1  1906       52
# 4     London 1908       1  1908       73

# %% [markdown]
# ## Check whether medal amendments due to doping are implemented
# Medals are sometimes stripped from athletes due to doping vialations (and awarded to 'true' winners retrospectively).

# %%
results[(results.Games=='2000 Summer') & (results.Sport=='Gymnastics') & (results.Sex=='F')].Event.value_counts()
# Out:
# Gymnastics Women's Individual All-Around    97
# Gymnastics Women's Horse Vault              84
# Gymnastics Women's Uneven Bars              84
# Gymnastics Women's Floor Exercise           83
# Gymnastics Women's Balance Beam             82
# Gymnastics Women's Team All-Around          72
# Name: Event, dtype: int64

# %%
results[(results.Games=='2000 Summer') 
        & (results.Event=="Gymnastics Women's Team All-Around") 
        & (results.Sex=='F') 
        & (results.Medal=='Bronze')].sort_values('Medal')
# Out:
#          index      ID                                 Name Sex   Age  Height  \
# 41093    41093   21181              Amy Yuen-Yee Chow (-Ho)   F  22.0   155.0
# 49151    49151   25312             Jamie Annette Dantzscher   F  18.0   152.0
# 50078    50078   25774  Dominique Margaux Dawes (-Thompson)   F  23.0   158.0
# 147833  147833   74186                  Kristen Ann Maloney   F  19.0   152.0
# 197674  197674   99252                       Mary Elise Ray   F  18.0   152.0
# 214995  214995  107925               Tasha Schwikert-Warren   F  15.0     NaN
#
#         Weight           Team  NOC        Games  Year  Season    City  \
# 41093     44.0  United States  USA  2000 Summer  2000  Summer  Sydney
# 49151     49.0  United States  USA  2000 Summer  2000  Summer  Sydney
# 50078     54.0  United States  USA  2000 Summer  2000  Summer  Sydney
# 147833    46.0  United States  USA  2000 Summer  2000  Summer  Sydney
# 197674    48.0  United States  USA  2000 Summer  2000  Summer  Sydney
# 214995     NaN  United States  USA  2000 Summer  2000  Summer  Sydney
#
#              Sport                               Event   Medal
# 41093   Gymnastics  Gymnastics Women's Team All-Around  Bronze
# 49151   Gymnastics  Gymnastics Women's Team All-Around  Bronze
# 50078   Gymnastics  Gymnastics Women's Team All-Around  Bronze
# 147833  Gymnastics  Gymnastics Women's Team All-Around  Bronze
# 197674  Gymnastics  Gymnastics Women's Team All-Around  Bronze
# 214995  Gymnastics  Gymnastics Women's Team All-Around  Bronze

# %% [markdown]
# Goldie Sayers 2008 Bronze isn't updated in the data, but 2000 USA women's team gymnastics is.
#
# While it could be interesting (and more accurate/realistic for games-time predictions) to predict both initial and stripped/reallocated medals, the 'long-term' awarded medals should be considered for this analysis (i.e. adjusted for known reawarded medals due to doping).

# %% [markdown]
# ### Import Wikipedia stripped medals data
# Next step is to load <a href="https://en.wikipedia.org/wiki/List_of_stripped_Olympic_medals">Wikipedia data on stripped medals</a> to ensure data is up to date.

# %%
stripped_wiki_tables = pd.read_html("https://en.wikipedia.org/wiki/List_of_stripped_Olympic_medals")
stripped = stripped_wiki_tables[1]
print(stripped.shape)
stripped.sort_values('Olympics', ascending=False).head(6)
# Out:
# (149, 6)
#                  Olympics                                  Athlete  \
# 148  2018 Winter Olympics  Curling team (Aleksandr Krushelnitckii)
# 147  2016 Summer Olympics                           Mikhail Aloyan
# 146  2016 Summer Olympics                        Gabriel Sîncrăian
# 145  2016 Summer Olympics                       Serghei Tarnovschi
# 144  2016 Summer Olympics                            Izzat Artykov
# 142  2014 Winter Olympics             Relay team (Evgeny Ustyugov)
#
#                           Country  Medal                       Event    Ref
# 148  Olympic Athletes from Russia    NaN      Curling, Mixed doubles  [111]
# 147                        Russia    NaN     Boxing, Men's flyweight  [110]
# 146                       Romania    NaN  Weightlifting, Men's 85 kg  [110]
# 145                       Moldova    NaN  Canoeing, Men's C-1 1000 m  [109]
# 144                    Kyrgyzstan    NaN  Weightlifting, Men's 69 kg  [108]
# 142                        Russia    NaN   Biathlon, Men's relay (Y)  [107]

# %%
stripped.Country.value_counts().head(10).plot(kind='barh', title='Top 10 countries with most stripped medals since 1978')
# Out:
# <AxesSubplot:title={'center':'Top 10 countries with most stripped medals since 1978'}>

# %% [markdown]
# **Event Key Letters (all should be 'NaN' in the results medal table for the stripped athletes, even for (Y)):**
# - (X) medal declared vacant
# - (Y) medal yet to be reallocated or declared vacant
# - (Z) not due to doping; all others were due to doping offenses
#
# Notes:
# 1. Pandas table scraping doesn't include the position of the stripped athletes (medals represented by image, not text), which makes the join potentially more complex (text-matching on name rather than filtering on medal)
# 2. The table doesn't list who the medals were reawarded to (in the cases where they were reawarded)
# 3. The results data doesn't include placings below Bronze (to infer updated results)
#
# **This means that further work is needed to update the data.**
#
# Checking stripped athletes are not awarded/listed in the results data could be done by first checking that medal awards were correct (i.e. stripped athletes don't have medals in events where recorded as stripped), then only updating those that require it.
#
# Two potential approaches:
# 1. See how well the Event names match/join to the main results table
# 2. Manually check (doing this one as suspect that most results are correct)
#
# Will develop algorithm to identify all athletes in results table who have had medals stripped. This will enable building models with or without the stripped medals accounted for. Updating medals after stripped medals requires more work for the reasons listed above.
#
# The Wikipedia data includes 2018 Winter games, which isn't in the results data. This row must be dropped to before performing analysis to identify stripped athletes (to avoid searching for athletes who aren't there).

# %%
stripped = stripped.drop(index=stripped[stripped.Olympics.str.contains('2018')].index[0])
stripped.tail()
# Out:
#                  Olympics                     Athlete     Country  Medal  \
# 143  2014 Winter Olympics  Relay team (Olga Zaitseva)      Russia    NaN
# 144  2016 Summer Olympics               Izzat Artykov  Kyrgyzstan    NaN
# 145  2016 Summer Olympics          Serghei Tarnovschi     Moldova    NaN
# 146  2016 Summer Olympics           Gabriel Sîncrăian     Romania    NaN
# 147  2016 Summer Olympics              Mikhail Aloyan      Russia    NaN
#
#                            Event    Ref
# 143  Biathlon, Women's relay (Y)  [105]
# 144   Weightlifting, Men's 69 kg  [108]
# 145   Canoeing, Men's C-1 1000 m  [109]
# 146   Weightlifting, Men's 85 kg  [110]
# 147      Boxing, Men's flyweight  [110]

# %% [markdown]
# ### Method for fuzzy matching stripped events onto results to automate checking for stripped medals in results
# 1. Data cleaning on stripped to match results (e.g. sport, Games)
# 2. Create a compound key of Games_Country_Sport to join stripped to results ready for fuzzy matching
# 3. Inner join stripped onto results using Games_Country_Sport key (resulting df should include all relevant events and athletes fields)
# 4. Iterate (apply) through games_country_sport
# 5. Fuzzy Match by name (take best match)
# 6. Fuzzy Match by event (take best match)
# 7. If team sport, get indices for whole team (event-based), else get best name match for event

# %% [markdown]
# 1. Clean stripped data to match results data

# %% [markdown]
# ### Notes on results of checking stripped medals
# 1. 2018 Curling: 2018 games aren't present in the results data--drop it

# %%
# cleaning functions to align stripped table to results table
def sport_from_event(event):
    sport = event.split(',')[0].title()
    
    # remove hyphen from Cross-Country Skiing for join to main results
    sport = sport.replace('-', ' ')
    
    # rename 'Equestrian' as 'Equestrianism'
    sport = sport.replace('Equestrian', 'Equestrianism')
    return sport

# %%
# extract sport from Event name--RESULT: cleaned
stripped['Sport'] = stripped.Event.apply(sport_from_event)
stripped.Sport.unique()
# Out:
# array(['Modern Pentathlon', 'Judo', 'Cycling', 'Swimming',
#        'Cross Country Skiing', 'Weightlifting', 'Athletics', 'Wrestling',
#        'Gymnastics', 'Alpine Skiing', 'Equestrianism', 'Rowing',
#        'Biathlon', 'Shooting', 'Canoeing', 'Bobsleigh', 'Boxing'],
#       dtype=object)

# %%
# check that Sports join correctly between tables (i.e. no NaNs)--RESULT: cleaned
stripped.Sport.value_counts().reset_index().merge(results.Sport.value_counts().reset_index(), 
                                                  left_on='index', 
                                                  right_on='index', 
                                                  how='left')
# Out:
#                    index  Sport_x  Sport_y
# 0          Weightlifting       50     3937
# 1              Athletics       50    38624
# 2              Wrestling       13     7154
# 3   Cross Country Skiing        9     9133
# 4                Cycling        5    10859
# 5               Biathlon        3     4893
# 6          Equestrianism        3     6344
# 7      Modern Pentathlon        2     1677
# 8              Bobsleigh        2     3058
# 9               Canoeing        2     6171
# 10              Shooting        2    11448
# 11            Gymnastics        2    26707
# 12                Rowing        1    10595
# 13         Alpine Skiing        1     8829
# 14                  Judo        1     3801
# 15              Swimming        1    23195
# 16                Boxing        1     6047

# %%
# check that Countries join correctly between tables (i.e. no NaNs)--RESULT: only 2018 issue with Russia (dropping rows from results)
stripped.Country.value_counts().reset_index().merge(results.Team.value_counts().reset_index(), 
                                                    left_on='index', 
                                                    right_on='index', 
                                                    how='left')
# Out:
#             index  Country   Team
# 0          Russia       43   4922
# 1         Belarus       11   1783
# 2         Ukraine       11   2511
# 3      Kazakhstan        9   1429
# 4   United States        8  17847
# 5        Bulgaria        7   3518
# 6          Turkey        5   1353
# 7           China        4   4975
# 8           Spain        4   5224
# 9      Uzbekistan        4    491
# 10        Hungary        4   6547
# 11        Romania        4   4303
# 12        Moldova        3    234
# 13         Sweden        3   8052
# 14        Armenia        3    221
# 15        Germany        2   9326
# 16         Greece        2   2976
# 17     Azerbaijan        2    283
# 18    North Korea        2    795
# 19        Finland        1   5379
# 20    Netherlands        1   5718
# 21      Lithuania        1    654
# 22        Georgia        1    286
# 23   Soviet Union        1   5535
# 24         Poland        1   6143
# 25         Norway        1   4708
# 26          Italy        1  10260
# 27        Jamaica        1    841
# 28           Cuba        1   2464
# 29        Bahrain        1    126
# 30         Canada        1   9279
# 31        Ireland        1   1309
# 32       Mongolia        1    550
# 33   Unified Team        1    832
# 34  Great Britain        1  11404
# 35     Kyrgyzstan        1    227

# %%
# clean games-year--RESULT: cleaned
stripped['Olympics'] = stripped['Olympics'].str.replace(' Olympics', '')
stripped.Olympics.unique()
# Out:
# array(['1968 Summer', '1972 Summer', '1976 Winter', '1976 Summer',
#        '1984 Summer', '1988 Summer', '1992 Summer', '2000 Summer',
#        '2002 Winter', '2004 Summer', '2006 Winter', '2008 Summer',
#        '2012 Summer', '2014 Winter', '2016 Summer'], dtype=object)

# %% [markdown]
# 2. Create compound key for join

# %%
stripped['games_country_sport'] = stripped.Olympics + '_' + stripped.Country + '_' + stripped.Sport
stripped.head(2)
# Out:
#       Olympics                                          Athlete   Country  \
# 0  1968 Summer  Modern Pentathlon team (Hans-Gunnar Liljenwall)    Sweden
# 1  1972 Summer                                 Bakhvain Buyadaa  Mongolia
#
#    Medal                    Event   Ref              Sport  \
# 0    NaN  Modern pentathlon, Team  [11]  Modern Pentathlon
# 1    NaN    Judo, Men's 63 kg (X)  [12]               Judo
#
#                     games_country_sport
# 0  1968 Summer_Sweden_Modern Pentathlon
# 1             1972 Summer_Mongolia_Judo

# %%
results['games_country_sport'] = results.Games + '_' + results.Team + '_' + results.Sport
results.head(2)
# Out:
#    index  ID       Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 0      0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer
# 1      1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer
#
#    Year  Season       City       Sport                         Event Medal  \
# 0  1992  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  2012  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN
#
#             games_country_sport
# 0  1992 Summer_China_Basketball
# 1        2012 Summer_China_Judo

# %% [markdown]
# 3. Inner-join tables for fuzzy matching

# %%
results_fields = ['games_country_sport', 'index', 'ID', 'Name', 'Sex', 'Team', 'Games', 'Sport', 'Event', 'Medal']
stripped_fields = ['games_country_sport', 'Olympics', 'Athlete', 'Country', 'Event']

# results_stripped = results.loc[~results.Medal.isna(), results_fields].merge(stripped[stripped_fields], 
#                                                                             how='inner',
#                                                                             on='games_country_sport',
#                                                                             suffixes=['_results', '_stripped'])

results_stripped = results[results_fields].merge(stripped[stripped_fields], 
                                                 how='inner',
                                                 on='games_country_sport',
                                                 suffixes=['_results', '_stripped'])

results_stripped[results_stripped.games_country_sport=='2012 Summer_Russia_Athletics'].shape
# Out:
# (1166, 14)

# %%
results[results.games_country_sport.isin(stripped.games_country_sport)].shape
# Out:
# (2262, 17)

# %%
results_stripped.shape
# Out:
# (5589, 14)

# %%
len(stripped.games_country_sport.unique())
# Out:
# 83

# %%
stripped.shape
# Out:
# (148, 8)

# %% [markdown]
# 4. Fuzzy-match on names and events (will use partial ratio because some names are listed in stripped table when part of team)

# %% [markdown]
# Testing best fuzzy-match approaches

# %%
str1 = "Denis Sergeyevich Alekseyev"
str2 = "Relay team (Denis Alexeev)"
print('rat: ',fuzz.ratio(str1, str2))
print('pr:  ',fuzz.partial_ratio(str1, str2))
print('tsortr: ',fuzz.token_sort_ratio(str1, str2))
print('tsetr: ',fuzz.token_set_ratio(str1, str2))
# Out:
# rat:  45
# pr:   42
# tsortr:  59
# tsetr:  59

# %%
str1 = "Olga Alekseyevna Zaytseva (-Augustin)"
str2 = "Olga Pyleva"
print('rat: ',fuzz.ratio(str1, str2))
print('pr:  ',fuzz.partial_ratio(str1, str2))
print('tsortr: ',fuzz.token_sort_ratio(str1, str2))
print('tsetr: ',fuzz.token_set_ratio(str1, str2))
# Out:
# rat:  38
# pr:   64
# tsortr:  40
# tsetr:  53

# %%
str1 = "Olga Valeryevna Pylyova-Medvedtseva (Zamorozova-)"
str2 = "Olga Pyleva"
print('rat: ',fuzz.ratio(str1, str2))
print('pr:  ',fuzz.partial_ratio(str1, str2))
print('tsortr: ',fuzz.token_sort_ratio(str1, str2))
print('tsetr: ',fuzz.token_set_ratio(str1, str2))
# Out:
# rat:  37
# pr:   64
# tsortr:  35
# tsetr:  53

# %% [markdown]
# Partial Ratio algorithm seems best for names

# %%
str1 = "Canoeing Men's Canadian Singles, 200 metres"
str2 = "Canoeing, Men's C-1 1000 m"
print('rat: ',fuzz.ratio(str1, str2))
print('pr:  ',fuzz.partial_ratio(str1, str2))
print('tsortr: ',fuzz.token_sort_ratio(str1, str2))
print('tsetr: ',fuzz.token_set_ratio(str1, str2))
# Out:
# rat:  61
# pr:   65
# tsortr:  57
# tsetr:  72

# %%
str1 = "Wrestling Men's Super-Heavyweight, Greco-Roman"
str2 = "Wrestling, Men's Greco-Roman +100 kg"
print('rat: ',fuzz.ratio(str1, str2))
print('pr:  ',fuzz.partial_ratio(str1, str2))
print('tsortr: ',fuzz.token_sort_ratio(str1, str2))
print('tsetr: ',fuzz.token_set_ratio(str1, str2))
# Out:
# rat:  66
# pr:   50
# tsortr:  73
# tsetr:  89

# %% [markdown]
# Token set ratio seems best for events

# %%
def fuzz_event_score(Sport, str1, str2):
    '''Remove the sport from the event names for matching to increase the matching effectiveness (sports will always match)'''
    
    # replace sport with blank and remove comma-space
    replacements = {Sport: '',
                    ', ': ''}
    
    for replacement in replacements:
        str1 = str1.replace(replacement, replacements[replacement])
        str2 = str2.replace(replacement, replacements[replacement])
    
    # use token sort ratio as proved best for matching events
    return fuzz.token_set_ratio(str1, str2)

# %%
results_stripped['name_match_score'] = results_stripped.apply(lambda row: fuzz.partial_ratio(row['Name'].lower(), row['Athlete'].lower()), 
                                                                axis=1)
results_stripped['event_match_score'] = results_stripped.apply(lambda row: fuzz_event_score(row['Sport'],
                                                                                                 row['Event_results'], 
                                                                                                 row['Event_stripped']), 
                                                                    axis=1)
results_stripped.sort_values('event_match_score', ascending=False).head(2)
# Out:
#                       games_country_sport   index     ID  \
# 109          2008 Summer_Russia_Athletics   24282  12731
# 2552  2000 Summer_United States_Athletics  110167  55703
#
#                                                    Name Sex           Team  \
# 109                           Anna Andreyevna Bogdanova   F         Russia
# 2552  Marion Lois Jones (-Hunter, -Montgomery, -Thom...   F  United States
#
#             Games      Sport                 Event_results Medal     Olympics  \
# 109   2008 Summer  Athletics  Athletics Women's Heptathlon   NaN  2008 Summer
# 2552  2000 Summer  Athletics   Athletics Women's Long Jump   NaN  2000 Summer
#
#                Athlete        Country                 Event_stripped  \
# 109   Tatyana Chernova         Russia  Athletics, Women's heptathlon
# 2552      Marion Jones  United States   Athletics, Women's long jump
#
#       name_match_score  event_match_score
# 109                 50                100
# 2552                75                100

# %%
def find_the_cheats(stripped_row):
    ''' Filters results_stripped based on the stripped row inputted, then uses best combination of matched name and event 
    to find the indices for the row in results. For team events, all athletes on the team are found.'''
    
    # filter by known games_country_sport, athlete, event (from stripped row)
    mask1 = results_stripped.games_country_sport==stripped_row.games_country_sport
    mask2 = results_stripped.Athlete==stripped_row.Athlete
    mask3 = results_stripped.Event_stripped==stripped_row.Event
    df = results_stripped[mask1 & mask2 & mask3]
    
    if df.shape[0] > 0:
        # find the best athlete and event match scores
        name_match_max = df.name_match_score.max()
        event_match_max = df.event_match_score.max()
        
        # filter down to best matches. If multiple, print stripped input and take top row
        mask_name = df.name_match_score==name_match_max
        mask_event = df.event_match_score==event_match_max

        if name_match_max > event_match_max:
            df_filtered = df[mask_name].sort_values('event_match_score').iloc[-1]
        else:
            df_filtered = df[mask_event].sort_values('name_match_score').iloc[-1]

        # if team event, extract all-team indices, else extract athlete index with the best name match from the event
        team_checks = ['team', 'two-man', 'four-man']
        athlete = stripped_row.Athlete
        if any(team_check in athlete.lower() for team_check in team_checks):
            idx = df[(df.Event_results==df_filtered.Event_results) & (df.Team==df_filtered.Team)]['index'].to_list()
        else:
            idx = df_filtered['index']

        # add column to track stripped medals if required
        stripped_col_name = 'stripped'
        if stripped_col_name not in results:
            results[stripped_col_name] = 0

        # flag all rows with stripped medals using indices
        results.loc[idx, stripped_col_name] = 1
        
        # return the indices for ref
        return idx

# %%
results['stripped'] = 0
stripped['idx'] = stripped.apply(lambda row: find_the_cheats(row), axis=1)

# %%
stripped.head()
# Out:
#       Olympics                                          Athlete  \
# 0  1968 Summer  Modern Pentathlon team (Hans-Gunnar Liljenwall)
# 1  1972 Summer                                 Bakhvain Buyadaa
# 2  1972 Summer                  Cycling team (Aad van den Hoek)
# 3  1972 Summer                                    Jaime Huélamo
# 4  1972 Summer                                      Rick DeMont
#
#          Country  Medal                                    Event   Ref  \
# 0         Sweden    NaN                  Modern pentathlon, Team  [11]
# 1       Mongolia    NaN                    Judo, Men's 63 kg (X)  [12]
# 2    Netherlands    NaN       Cycling, Men's team time trial (X)  [13]
# 3          Spain    NaN  Cycling, Men's individual road race (X)  [13]
# 4  United States    NaN          Swimming, Men's 400 m freestyle   [8]
#
#                Sport                   games_country_sport  \
# 0  Modern Pentathlon  1968 Summer_Sweden_Modern Pentathlon
# 1               Judo             1972 Summer_Mongolia_Judo
# 2            Cycling       1972 Summer_Netherlands_Cycling
# 3            Cycling             1972 Summer_Spain_Cycling
# 4           Swimming    1972 Summer_United States_Swimming
#
#                                idx
# 0          [67992, 105173, 139079]
# 1                            12967
# 2  [53695, 128599, 193127, 248354]
# 3                           100473
# 4                            53637

# %%
results[results.stripped==1].sort_values('Games').head()
# Out:
#          index      ID                         Name Sex   Age  Height  Weight  \
# 139079  139079   69868       Hans-Gunnar Liljenwall   M  27.0   188.0    74.0
# 67992    67992   34729        Bjrn Bernt Ewald Ferm   M  24.0   180.0    72.0
# 105173  105173   53227       Hans Olov Dan Jacobson   M  21.0   180.0    71.0
# 248354  248354  124333   Adriaan "Aad" van den Hoek   M  20.0   186.0    77.0
# 53637    53637   27506  Richard James "Rick" DeMont   M  16.0   180.0    69.0
#
#                  Team  NOC        Games  Year  Season         City  \
# 139079         Sweden  SWE  1968 Summer  1968  Summer  Mexico City
# 67992          Sweden  SWE  1968 Summer  1968  Summer  Mexico City
# 105173         Sweden  SWE  1968 Summer  1968  Summer  Mexico City
# 248354    Netherlands  NED  1972 Summer  1972  Summer       Munich
# 53637   United States  USA  1972 Summer  1972  Summer       Munich
#
#                     Sport                                         Event Medal  \
# 139079  Modern Pentathlon                  Modern Pentathlon Men's Team   NaN
# 67992   Modern Pentathlon                  Modern Pentathlon Men's Team   NaN
# 105173  Modern Pentathlon                  Modern Pentathlon Men's Team   NaN
# 248354            Cycling  Cycling Men's 100 kilometres Team Time Trial   NaN
# 53637            Swimming           Swimming Men's 400 metres Freestyle   NaN
#
#                          games_country_sport  stripped
# 139079  1968 Summer_Sweden_Modern Pentathlon         1
# 67992   1968 Summer_Sweden_Modern Pentathlon         1
# 105173  1968 Summer_Sweden_Modern Pentathlon         1
# 248354       1972 Summer_Netherlands_Cycling         1
# 53637     1972 Summer_United States_Swimming         1

# %% [markdown]
# ### Export stripped results data for inspection

# %%
stripped_results_filename = r'stripped_results.csv'
cols = ['Games', 'Name', 'Team', 'Medal', 'Event', 'stripped']
results.loc[results.stripped==1, cols].sort_values(['Games', 'Team']).to_csv(os.path.join(path, stripped_results_filename))
print('Done')
# Out:
# Done

# %% [markdown]
# ## Aggregating data to medals per country per event
# Two approaches here:
# 1. Not considering stripped medals (some are stripped in the results data already)
# 2. Considering stripped medals (currently no replacement/update of other medals as not all placings included in the data. Could scrape IOC website for better results data).
#
# **Note:** Medal tables are typically considered by event (not individuals), so the groupby needs to be event based and not sum all individual athlete medals per event

# %% [markdown]
# ### Not considering stripped medals
#
# Plan
# 1. one-hot encode medals column for results and join back on
# 2. groupby games, team, event using max as the aggregation function (consider required columns here)
# 3. reset index..?
#
# Issues
# - What if two athletes from the same nation tie for a medal? The max-groupby only counts one medal per games/event/team combination...

# %%
results.head(2)
# Out:
#    index  ID       Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 0      0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer
# 1      1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer
#
#    Year  Season       City       Sport                         Event Medal  \
# 0  1992  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  2012  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN
#
#             games_country_sport  stripped
# 0  1992 Summer_China_Basketball         0
# 1        2012 Summer_China_Judo         0

# %%
results.Medal.value_counts()
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %% [markdown]
# 1. One-Hot Encode Medals column

# %%
keep_cols = ['Team', 'NOC', 'Games', 'City', 'Sport', 'Event', 'Medal_Gold', 'Medal_Silver', 'Medal_Bronze']
gsb = pd.get_dummies(results, columns=['Medal'])[keep_cols]
gsb[gsb.Medal_Gold==1].head(2)
# Out:
#               Team  NOC        Games    City       Sport  \
# 3   Denmark/Sweden  DEN  1900 Summer   Paris  Tug-Of-War
# 42         Finland  FIN  1948 Summer  London  Gymnastics
#
#                                Event  Medal_Gold  Medal_Silver  Medal_Bronze
# 3        Tug-Of-War Men's Tug-Of-War           1             0             0
# 42  Gymnastics Men's Team All-Around           1             0             0

# %% [markdown]
# 2. Group by Games, Team, Event (what about tied medals by the same team??)

# %%
len(gsb.Event.unique())
# Out:
# 765

# %%
event_grouped = gsb.groupby(['Games', 'Team', 'Event']).max().reset_index()
event_grouped.head()
# Out:
#          Games                     Team                         Event  NOC  \
# 0  1896 Summer                Australia  Athletics Men's 1,500 metres  AUS
# 1  1896 Summer                Australia    Athletics Men's 800 metres  AUS
# 2  1896 Summer                Australia      Athletics Men's Marathon  AUS
# 3  1896 Summer                Australia          Tennis Men's Singles  AUS
# 4  1896 Summer  Australia/Great Britain          Tennis Men's Doubles  GBR
#
#      City      Sport  Medal_Gold  Medal_Silver  Medal_Bronze
# 0  Athina  Athletics           1             0             0
# 1  Athina  Athletics           1             0             0
# 2  Athina  Athletics           0             0             0
# 3  Athina     Tennis           0             0             0
# 4  Athina     Tennis           0             0             1

# %%
team_grouped = event_grouped.groupby(['Games', 'Team']).sum().reset_index()
team_grouped['Medal_Total'] = team_grouped.Medal_Gold + team_grouped.Medal_Silver + team_grouped.Medal_Bronze
team_grouped.head()
# Out:
#          Games                           Team  Medal_Gold  Medal_Silver  \
# 0  1896 Summer                      Australia           2             0
# 1  1896 Summer        Australia/Great Britain           0             0
# 2  1896 Summer                        Austria           2             1
# 3  1896 Summer                        Denmark           1             2
# 4  1896 Summer  Ethnikos Gymnastikos Syllogos           0             0
#
#    Medal_Bronze  Medal_Total
# 0             0            2
# 1             1            1
# 2             2            5
# 3             3            6
# 4             1            1

# %%
[print(team) for team in team_grouped.Team.unique()]
# Out:
# Australia
# Australia/Great Britain
# Austria
# Denmark
# Ethnikos Gymnastikos Syllogos
# France
# Germany
# Great Britain
# Great Britain/Germany
# Greece
# Greece-1
# Greece-2
# Greece-3
# Hungary
# Italy
# Sweden
# Switzerland
# United States
# A North American Team
# Alcyon-6
# Alcyon-7
# Amateur Athletic Association
# Amulet-3
# Amulet-7
# Argentina
# Ariette-10
# Ariette-8
# Aschenbrodel
# Austria-1
# BLO Polo Club, Rugby
# Baby-1
# Baby-9
# Bagatelle Polo Club, Paris
# Belgium
# Belgium-1
# Belgium-2
# Bohemia
# Bohemia/Great Britain
# Bona Fide
# Brazil
# Brussels Swimming and Water Polo Club
# Brynhild-2
# C.V.A.-14
# C.V.A.-7
# Canada
# Carabinier-15
# Carabinier-5
# Cercle Nautique de Reims-4
# Cercle de l'Aviron Roubaix-4
# Cicely-1
# Cinara-13
# Club Nautique de Dieppe-5
# Club Nautique de Franais-1
# Club Nautique de Lyon-2
# Colette-10
# Colette-12
# Compigne Polo Club
# Crabe I-11
# Crabe I-2
# Crabe I-3
# Crabe II-1
# Crabe II-12
# Crabe II-4
# Crocodile-11
# Crocodile-13
# Cuba
# Demi-Mondaine-15
# Demi-Mondaine-17
# Denmark/Sweden
# Deutscher Schwimm Verband Berlin
# Devon and Somerset Wanderers
# Dick-8
# Ducky-16
# Ducky-4
# Esterel-1
# Fantlet-2
# Fantlet-7
# Favorite Hammonia-3
# Favorite-1
# Favorite-17
# Femur-1
# Femur-18
# Formosa
# Foxhunters Hurlingham
# France-1
# France-2
# France-3
# France-4
# France/Great Britain
# Frankfurt Club
# Freia-19
# Freia-5
# Frimousse
# Galopin-20
# Galopin-9
# Germania Ruder Club, Hamburg
# Germania Ruder Club, Hamburg-2
# Germany-1
# Giselle-6
# Gitana-2
# Gitana-21
# Great Britain-1
# Great Britain-2
# Gwendoline-2
# Gwendoline-22
# Gyp-23
# Gyp-6
# Haiti
# Hb-20
# Hb-24
# India
# Iran
# Jeanette-25
# Jeannette-18
# Laurea-1
# Lerina
# Libellule de Paris
# Libellule de Paris-3
# Ludwigshafener Ruder Verein-1
# Luxembourg
# Mamie-4
# Mamie-6
# Marsouin-26
# Marsouin-8
# Martha-1
# Martha-27
# Mascaret-28
# Mascaret-4
# Mascotte
# Mignon-29
# Mignon-3
# Minerva Amsterdam
# Moseley Wanderers
# Nan-2
# Netherlands
# Nina Claire-2
# Nina Claire-30
# Norway
# Olle
# Osborne Swimming Club, Manchester
# Peru
# Pettit-Poucet-6
# Pierre et Jean-3
# Pierre et Jean-4
# Pirouette-31
# Pirouette-5
# Plume-Patte-5
# Plume-patte-32
# Pupilles de Neptune de Lille #1-3
# Pupilles de Neptune de Lille #2-1
# Pupilles de Neptune de Lille-1
# Quand-Mme-2
# Quand-Mme-33
# Racing Club de France
# Ral-Club Barcelona
# Romania
# Rowing Club Castillon-3
# Royal Club Nautique de Gand
# Rozenn-3
# Russia
# Russia-1
# Sarcelle-3
# Sarcelle-35
# Scamasaxe-2
# Scamasaxe-3
# Scamasaxe-34
# Scotia
# Sidi Fekkar-36
# Sidi-Fekkar-14
# Singy-37
# Singy-7
# Societ Nautique de la Marne
# Societ Nautique de la Marne-1
# Societ Nautique de la Marne-3
# Souriceau-38
# Souriceau-4
# Souvenance
# Spain
# Spain-1
# Stade Franais AC-2
# Suzon IV-39
# Suzon IV-5
# Tornade-16
# Tournade-40
# Tritons Lillois-2
# Turquoise-1
# Turquoise-3
# USFSA
# Union des Socits Franais de Sports Athletiques
# United States/France
# United States/Great Britain
# Univ. of Brussels
# Upton Park FC
# Verveine-19
# Verveine-41
# Vesper Boat Club
# Atalanta Boat Club-1
# Atalanta Boat Club-2
# Boer Team
# Boston Archers
# Central Turnverein, Chicago
# Century Boat Club-1
# Chicago Archers
# Chicago Athletic Association
# Chicago Athletic Association-2
# Christian Brothers' College-1
# Cincinnati Archers
# Concordia Turnverein, St Louis
# Davenport Turngemeinde, Davenport
# Galt Football Club
# Germany/United States
# Independent Rowing Club-3
# La Salle Turnverein, Chicago
# Milwaukee Athletic Club-1
# Milwaukee Turnverein, Milwaukee
# Missouri Athletic Club-3
# Mohawk Indians-2
# Mound City Rowing Club-2
# New York Athletic Club
# New York Athletic Club #1-1
# New York Athletic Club #2-4
# New York Athletic Club-1
# New York Athletic Club-4
# New York Turnverein, New York
# Newfoundland
# Norwegier Turnverein, Brooklyn
# Pan-Hellenic Athletic Club
# Passaic Turnverein, Passaic
# Philadelphia Turngemeinde, Philadelphia
# Potomac Archers
# Ravenswood Boat Club-2
# Seawanhaka Boat Club-1
# Socialer Turnverein, Detroit
# South Africa
# South St Louis Turnverein, St Louis
# St. Louis Amateur Athletic Association
# St. Louis Southwest Turnverein #1-2
# St. Louis Southwest Turnverein #2-3
# St. Rose-2
# Toronto Argonauts
# Trans-Mississippi Golf Association-2
# Turnverein Vorwrts, Chicago
# Turnverein Vorwrts, Cleveland
# United States Golf Association-3
# United States-1
# United States-10
# United States-11
# United States-12
# United States-13
# United States-14
# United States-2
# United States-3
# United States-4
# United States-5
# United States-6
# United States-7
# United States-8
# United States-9
# Western Golf Association-1
# Western Rowing Club-3
# Winnipeg Shamrocks-1
# Athens-2
# Barion/Bari-2
# Bucintoro Venezia
# Bucintoro Venezia-1
# Crete
# Dansk Idrts Forbund
# Egypt
# Finland
# Greece-4
# Large boat, Central Naval Prep School "Poros"-1
# Lemzos Thorichton "Psara"-3
# Lemzos Thorichton "Spetsai"-4
# Life boat naval ship "Spetsai"-1
# Marinai della nave da guerra "Varese"
# Nautikos Omilos-3
# Omas Helliniki P. S.
# Omilos Ereton Peiraios-2
# Omilos Ereton Smyrnis
# Panhellenios Gymnastikos Syllogos-1
# Peiraikos Syndesmos-2
# Phalainis ton Thorichtou "Hydra"-2
# Phalainis ton Thorichtou "Psara"-3
# Pistoja/Firenze
# Roma
# Smyrna
# Socit Nautique de Bayonne-1
# Socit Nautique de Bayonne-2
# Socit Nautique de la Basse Seine-1
# Socit Nautique de la Basse Seine-2
# Thessalonki-1
# Turkey
# Amstel Amsterdam
# Argonaut Rowing Club
# Australasia
# Berliner Ruderclub
# Cambridge University Boat Club-2
# Camille
# Cobweb-1
# Cornwall
# Dormy-1
# Dylan-2
# England-1
# Fram
# Freja
# Germany-2
# Great Britain-3
# Great Britain-4
# Guyoni
# Gyrinus-1
# Hera-1
# Heroine
# Hurlingham-2
# Iceland
# Ireland-2
# Ireland-3
# K Division Metropolitan Police Team-3
# Leander Club #1-1
# Leander Club #2-2
# Leander Club-1
# Leander Club-2
# Liverpool Police Team-2
# London City Police-1
# Magdalen College Boat Club-1
# Mouchette-2
# Norwegian Rowing Association
# Pannonia RC/National RC
# Quicksilver-2
# Roehampton-1
# Saga-2
# Scotland-3
# Sea Dog-2
# Sibindi-2
# Sorais-2
# Vinga-1
# Wales-4
# Wolseley-Siddeley-1
# Zut
# Berliner Ruderclub Sport-Borussia-1
# Berliner Ruderverein von 1876-2
# Bohemia-1
# Bohemia-2
# Bohemia-3
# Bylina-2
# Chile
# Denmark-1
# Denmark-2
# Denmark-3
# Denmark-4
# England
# Erna Signe
# Finn II
# Gallia II
# Gteborgs Roddfrening-2
# Gteborgs Roddklubb-1
# Heatherbell
# Helsingfors R. K.
# Hungaria Evezos Egylet
# Hungary-2
# Hungary-3
# Ireland
# Japan
# K.S.S.S. 1912-2
# Kerstin-1
# Kitty-1
# Kristiania Roklub
# Kristiania Roklub-1
# Lucky Girl-1
# Ludwigshafener Ruderverein
# Mac Miche
# Magda IX
# Marga-2
# New College, Oxford-2
# Nina
# Norman-1
# Norway-1
# Norway-2
# Norway-3
# Nurdug II
# Nykjbings paa Falster
# Ormsund Roklub-2
# Poland
# Polyteknisk Roklub-1
# Portugal
# R.-V. Germania, Leitmeritz
# Roddklubben af 1912-1
# Roddklubben af 1912-2
# Roklubb Kbnhavn-2
# Sans Atout-1
# Sass-2
# Scotland
# Scotland-2
# Serbia
# Socit Nautique de Bayonne
# Sonja II
# Studenternes Roklub-2
# Sweden-1
# Sweden-2
# Sweden-3
# Sweden-4
# Sydney Rowing Club
# Taifun
# Thames Rowing Club
# Unknown
# Vaxholm Roddklubb
# rn-2
# Ancora
# Antwerpia V
# Atlanta
# Beatrijs III-1
# Belgium-3
# Belgium-4
# Boreas-2
# Brat
# Czechoslovakia
# Czechoslovakia-1
# Czechoslovakia-3
# Edelweiss II-1
# Eleda
# Elsie
# Estonia
# Fornebo
# Heira II
# Irene
# Jo
# Kullan
# Lyn-2
# Marmi II-1
# Monaco
# Mosk II
# New Zealand
# Oranje
# Rose Pompon
# Sif
# Sildra-1
# South Africa-1
# South Africa-2
# Spain-2
# Stella-2
# Suzy-2
# Tan-Fe-Pah
# Yugoslavia
# Aloha II
# Amolgavar
# Argentina-1
# Argentina-2
# Bera
# Blue Red
# Bonzo
# Bulgaria
# Ciss
# Czechoslovakia-2
# Ecuador
# Elisabeth V
# Emily
# Finland-1
# Finland-2
# Hatuey
# Hungary-1
# India-1
# India-2
# Ireland-1
# Japan-1
# Japan-2
# Latvia
# Lithuania
# Mebi
# Mexico
# Namoussa
# Philippines
# Sandra
# Switzerland-1
# Switzerland-2
# Uruguay
# Willem-Six
# Italy-1
# Italy-2
# Nepal
# Babe
# Bamba
# Camelia
# Cupidon III
# Cupidon Viking
# Feo
# Frieda
# Fruits
# Hi-Hi
# Hollandia
# Hungaria
# Ingegerd
# Kemphaan
# L'Aile VI
# Malta
# Noreg
# Norna
# Pan
# Panama
# Sylvia
# Tutti V
# Twins II
# Ubu
# Zimbabwe
# Austria-2
# Romania-1
# Romania-2
# Angelita
# Bissbi
# Caprice
# China
# Colombia
# El Salvador
# Gallant
# Guatemala
# Holland
# Joy
# Jupiter
# Santa Maria
# Springbok
# Swedish Star
# Tramontane
# Venezuela
# Windor
# Canada-1
# Canada-2
# Afghanistan
# Angerburg
# Anitra
# Augsburg
# Bem II
# Bermuda
# Bolivia
# Brandenburg
# Bremen
# Breslau
# Costa Rica
# Cuxhaven
# Danuta
# Danzig
# DeRuyter
# Dresden
# EA II
# Esperia
# Essen
# Fada
# Freddy
# Germania II
# Gustel V
# Hamburg
# Hannover
# Heidelberg
# Ilderim
# Italia
# KNS
# Kiel
# Kln
# Knigsberg
# Konstanz
# Lalage
# Lbeck
# Leipzig
# Liechtenstein
# Lully II
# Lynn
# Mainz
# Marmara
# Matrero II
# May Be
# Myojo
# Mystery
# Nrnberg
# Paka
# Pegaso
# Potsdam
# Qu'Importe
# Rostock
# Saskia
# Sheerio
# Silja
# Sunshine
# Three Star Too
# Vicking
# Wannsee
# Wiking
# Ylliam II
# Luxembourg-1
# Luxembourg-2
# Acturus
# Ali-Baba II
# Allegro
# Andorinha
# Antares
# Apache
# Argus
# Ariel
# Ausonia
# Buscape II
# Ceres II
# Chance
# Ciocca II
# Djinn
# Dolfijn
# Donar III
# Enotria
# Espardate
# Galerna
# Gem II
# Guyana
# Hilarius
# Iraq
# Jamaica
# Johan
# Kurush II
# LaBandera
# Lebanon
# Legionario
# Llanoria
# Lotta IV
# Lucky Star
# Margaret
# Moorina
# Morena
# Myanmar
# Nephos I
# Nora
# Nortazo
# Pakistan
# Pampero
# Puerto Rico
# Raili
# Red Indian
# Rhythm
# Scaup
# Singapore
# Slaghoken
# Snap
# South Korea
# Sri Lanka
# St. Margrite
# Starita
# Swift
# Symphony
# Syria
# The Cloud
# Trinidad and Tobago
# Vinha
# Ylliam VII
# 30. Februar
# Alcaid
# Ali-Baba IV
# Arcturus
# Bahamas
# Bu III
# Burevestnik
# Ciocca
# Comanche
# Complex II
# Damoiselle
# Eissero VI
# Elisabeth X
# Encore
# Escapade
# Espadarte
# Fortuna
# Galatea II
# Gem III
# Ghana
# Girl Pat
# Gullvinge
# Gustel X
# Hirondelle
# Hojwa
# Hong Kong
# Hornet
# Indonesia
# Israel
# Jet
# Jill
# Korshun
# Kurush IV
# Marie-Tim
# May Be VII
# Merope
# Mirtala
# Netherlands Antilles
# Nigeria
# Nirwana
# Paka V
# Primorka
# Ralia
# Saar
# Sabre
# Shoveller
# Sjhxa
# Skidoo
# Snude
# South Vietnam
# Soviet Union
# Teresita
# Thailand
# Thalatta
# Tim-Tam III
# Titia
# Tom Kyle
# Tornado
# Trickson VI
# Tu-Fri
# Unique
# Uragan
# Virginie
# Whirlaway
# Yeoman
# Ylliam VIII
# Aretusa
# Beaver
# Bluebottle
# Buraddoo
# Cambodia
# Canopus
# Chinese Taipei
# Chuckles
# Covunco III
# Druzhba
# Ethiopia
# Falcon IV
# Faneca
# Fiji
# Gam II
# Gem IV
# Gilliatt V
# Gustl XI
# Impala
# Inca
# Jest
# Kannibaltje
# Kathleen
# Kenya
# Kingfisher
# Kon-Tiki
# Liberia
# Malaya
# Manana
# Merope III
# Naiad
# Neptun II
# Nikh
# North Borneo
# Pam
# Pan II
# Paula
# Red Dragon
# Rika II
# Romolo
# Rush IV
# Rush V
# Slaghoken II
# Spirit III
# Starlight III
# Tichiboo
# Tilly
# Tineke
# Tip
# Tomahawk II
# Tulilind
# Twins VIII
# Uganda
# Viking
# Vision
# Wendehals
# Xantippa
# Yeoman V
# Poland-1
# Poland-2
# Aldebaran II
# Aletta
# Ali-Baba VI
# Ardilla
# Argo II
# Astrid III
# Baccara
# Bajazzo
# Balaton
# Ballerina IV
# Bella
# Bellatrix IX
# Bermudes
# Bermudian
# Bim
# Boreas
# Bronia
# Calcinhas
# Calypse II
# Cha-Cha III
# Chamukina
# Chok
# Ciocca III
# Circus
# Combine
# Daisy
# Damoiselle IV
# Danaldo
# Dinah V
# Espuma del Mar
# Evita VI
# Falcon VI
# Fantasio III
# Frip IV
# Gabbiano
# Galejan
# Gem VII
# Grifo III
# Hakahana
# Harmony
# Inga-Lill XXXXIII
# John B
# June Climene
# Lasha
# Lett
# Ma'Lindo
# Macky VI
# Mad Dog
# Maid of Lebanon
# Mari
# May-Be 1960
# Meteor
# Minotaur
# Mizar
# Morocco
# Nirefs
# Nokaut II
# Oleander II
# Olimpia
# Olympion
# Pakaria
# Partenope
# Pasodoble
# Patricia
# Peri
# Persey
# Pimm
# Posillipo III
# Rhodesia
# Rififi
# SagaII
# Salamander
# San Marino
# Scram
# Shrew II
# Siames-Cat
# Sirene
# Sjovinge
# Skum
# Snowten III
# Spirit VI
# Struten
# Sudan
# Surprise
# Tajamar
# Tango
# Tengiri
# Terrible
# Three Leaves
# Trintel II
# Tunisia
# Twinkle
# United Arab Republic
# Venilia
# Vesania
# Viktoriya
# Vim III
# Voloira II
# Web II
# West Indies Federation
# Yangon
# Yeoman VII
# Zefyros
# Germany-3
# Soviet Union-1
# Soviet Union-2
# Acipactli
# Akatonbo
# Alain IV
# Aldebaran
# Algeria
# Ali-Baba IX
# Almaz
# Andromeda
# Aphrodite
# Argeste
# Barco Deloro
# Barrenjoey
# Bellatrix XIII
# Bingo
# Brigantia
# Cambria
# Cameroon
# Chad
# Chaje II
# Clementine V
# Congo (Brazzaville)
# Cote d'Ivoire
# Diablo
# Dominican Republic
# Firebird II
# Fram III
# Gem
# Glider
# Glisten
# Grifo IV
# Grifone
# Guanahani
# GyoshuII
# Hayama
# Humbug V
# Kalayaan
# Kuling
# Lady C
# Linglom
# Lucky
# Madagascar
# Malaysia
# Mali
# Maryke
# Miss Denmark 1964
# Miss Nippon IV
# Miss Nippon V
# MitaII
# Mongolia
# Monica
# Mutafo
# Nausikaa 4
# Niger
# Oleander XII
# Olen
# Pandora
# Peri II
# Phoenix
# Pigoule
# Pousse-Moi Pas VII
# Proteus II
# Rampage
# Riccar
# Roy
# Rush VII
# Senegal
# Serendipity
# Squid III
# State VI
# Subbnboana
# Syndi
# Tantalus
# Tanzania
# Tlaloc
# Umberta V
# Vento Sul
# Web III
# White Lady
# Widgeon
# Xolotl
# Yeoman XII
# Zambia
# Canada-3
# North Korea
# Barbados
# Belize
# Central African Republic
# Congo (Kinshasa)
# East Germany
# Guinea
# Honduras
# Kuwait
# Libya
# Nicaragua
# Paraguay
# Sierra Leone
# Suriname
# United States Virgin Islands
# West Germany
# East Germany-1
# East Germany-2
# Soviet Union-3
# West Germany-1
# West Germany-2
# West Germany-3
# Albania
# Benin
# Burkina Faso
# East Germany-3
# Gabon
# Lesotho
# Malawi
# Poland-3
# Saudi Arabia
# Somalia
# Swaziland
# Togo
# Yugoslavia-1
# Yugoslavia-2
# Andorra
# Antigua and Barbuda
# Cayman Islands
# Papua New Guinea
# Italy-3
# Angola
# Botswana
# Cyprus
# Jordan
# Laos
# Mozambique
# Seychelles
# Vietnam
# Bahrain
# Bangladesh
# Bhutan
# British Virgin Islands
# Djibouti
# Equatorial Guinea
# Gambia
# Grenada
# Mauritania
# Mauritius
# North Yemen
# Oman
# Qatar
# Rwanda
# Samoa
# Solomon Islands
# Tonga
# United Arab Emirates
# Chinese Taipei-1
# Chinese Taipei-2
# American Samoa
# Aruba
# China-1
# China-2
# Cook Islands
# Guam
# Hong Kong-1
# Hong Kong-2
# Maldives
# Nigeria-1
# Nigeria-2
# Saint Vincent and the Grenadines
# South Korea-1
# South Korea-2
# South Yemen
# Vanuatu
# Australia-1
# Australia-2
# Bulgaria-1
# Bulgaria-2
# Mexico-1
# Mexico-2
# New Zealand-1
# New Zealand-2
# Portugal-1
# Portugal-2
# United States Virgin Islands-1
# United States Virgin Islands-2
# Bosnia and Herzegovina
# Croatia
# Individual Olympic Athletes
# Indonesia-1
# Indonesia-2
# Japan-3
# Malaysia-1
# Malaysia-2
# Namibia
# North Korea-1
# North Korea-2
# Slovenia
# Unified Team
# Unified Team-1
# Unified Team-2
# Yemen
# Jamaica-1
# Jamaica-2
# Latvia-1
# Latvia-2
# Monaco-1
# Monaco-2
# Puerto Rico-1
# Puerto Rico-2
# Unified Team-3
# Armenia
# Belarus
# Czech Republic
# Czech Republic-1
# Czech Republic-2
# Georgia
# Kazakhstan
# Kyrgyzstan
# Moldova
# Russia-2
# Russia-3
# Slovakia
# Ukraine
# Ukraine-1
# Ukraine-2
# Uzbekistan
# Uzbekistan-1
# Uzbekistan-2
# Azerbaijan
# Brazil-1
# Brazil-2
# Brunei
# Burundi
# Cape Verde
# Comoros
# Dominica
# Guinea Bissau
# Macedonia
# Mauritius-1
# Mauritius-2
# Nauru
# Netherlands-1
# Netherlands-2
# Palestine
# Saint Kitts and Nevis
# Saint Lucia
# Sao Tome and Principe
# Serbia and Montenegro
# Slovakia-1
# Slovakia-2
# Tajikistan
# Thailand-1
# Thailand-2
# Turkmenistan
# Australia-3
# Eritrea
# Federated States of Micronesia
# Palau
# China-3
# Israel-1
# Israel-2
# Kiribati
# Singapore-1
# Singapore-2
# Slovenia-1
# Slovenia-2
# Timor Leste
# Belarus-1
# Belarus-2
# Bonaparte
# Brentina
# Briar
# Calimucho
# Clearwater
# Cuba-1
# Cuba-2
# Diabolo St Maurice
# Digby
# Don Schufro
# Dow Jones
# Elvis Va
# Floresco
# Galopin De La Font
# Gran Gesto
# Greenoaks Dundee
# Lancet
# Marshall Islands
# Mistral Hojris
# Montenegro
# Mythilus
# Nadine
# Notavel
# Orion
# Oxalis
# Pop Art
# Quando Quando
# Rambo
# Ravel
# Relampago
# Salinero
# Satchmo
# Solos Carex
# Sunrise
# Tuvalu
# Whisper
# Whitini Star
# Serbia-1
# Serbia-2
# Kosovo
# Refugee Olympic Athletes
# South Sudan
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]
