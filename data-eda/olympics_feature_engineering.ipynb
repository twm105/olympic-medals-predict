# %% [markdown]
# # Feature Engineering for Olympic results
# Purpose of this workbook is to build a dataset ready for proper EDA and modelling.
#
# Plan initially is to join historic population and GDP per capita data onto the Olympics results data scraped from IOC website. Will also add the home country to each games (home advantage is reported as a key predictor of olympic success).
#
# The population and GDPpc data will need joining based on country (fuzzy match perhaps needed where country names don't perfectly align) and also their values will need interpolating in many cases onto the dates of each games (data starts very course for further back in time, and shifts to annual data for more recent dates).
#
# ### Handling dates outside the data ranges
# Some games data for some countries will be outside of the range the population and GDPpc data too. Three options for this:
# 1. 'Saturated': Take value of nearest date (e.g. oldest data point)
# 2. Extrapolated: Make a linear extrapolation based on the closest two points
# 3. Ignore values that can't be interpolated
#
# Option 3 is preferable initially because it doesn't make any assumptions outside of the known datasets, and it is expected that there will be plenty of observations in the data to train models with.

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from fuzzywuzzy import fuzz
from tqdm import tqdm
import numpy as np
import os
# Out:
# C:\Users\tmais\AppData\Local\Programs\Python\Python39\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# ### Utility functions

# %% [markdown]
# Interpolate population data onto results

# %%
def historical_interp(df_lookup, country_code, year, y_col, country_code_col='alpha_3', x_col='year'):
    '''Function that interpolates historic population data for a year of an Olympic games for a given team'''
    
    if country_code is not None:
        df_history = df_lookup.loc[df_lookup[country_code_col]==country_code, [x_col, y_col]].astype('float')
        if df_history.shape[0] > 1:
            df_interp = np.interp([year],
                                  df_history[x_col],
                                  df_history[y_col],
                                          left=np.nan,
                                          right=np.nan)
            return df_interp[0]
        else:
            return np.nan
    else:
        return np.nan

# %% [markdown]
# ## Importing the summer Olympics results

# %%
# load results. Path set to relative in repo (i.e. assumes the same folder)
project_path = r''
results_fname = r'olympics_summer_results.csv'
results = pd.read_csv(os.path.join(project_path, results_fname))
results_f = results.copy()
results_f.head()
# Out:
#          games    country alpha_3 ioc_code  host  year  gold  silver  bronze  \
# 0  Athens 1896  Australia     AUS      AUS     0  1896     2       0       0
# 1  Athens 1896    Austria     AUT      AUT     0  1896     2       1       2
# 2  Athens 1896   Bulgaria     BGR      BUL     0  1896     0       0       0
# 3  Athens 1896      Chile     CHL      CHI     0  1896     0       0       0
# 4  Athens 1896    Denmark     DNK      DEN     0  1896     1       2       3
#
#    total  summer  associate_nations
# 0      2       1                NaN
# 1      5       1                NaN
# 2      0       1                NaN
# 3      0       1                NaN
# 4      6       1                NaN

# %% [markdown]
# ## Final cleaning of ISO Alpha 3 codes
# Some codes have errors in them (probably due to the use of fuzzy matching). These need resolving to ensure that countries can be successfully visualised without incorrect duplicates.

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
countries_codes = results_f[['country', 'alpha_3', 'ioc_code']].drop_duplicates().sort_values('country')
def build_google_iso_search(row):
    country = row['country'].replace(' ', '+')
    ggl_url = f'www.google.com/search?q=iso+alpha3+{country}'
    return ggl_url
countries_codes['google_iso'] = countries_codes.apply(lambda row: build_google_iso_search(row), axis=1)
print(countries_codes)
# pd.reset_option('display.max_rows')
# Out:
#                                     country alpha_3 ioc_code  \
# 267                             Afghanistan     AFG      AFG
# 809                                 Albania     ALB      ALB
# 602                                 Algeria     DZA      ALG
# 1244                         American Samoa     ASM      ASA
# 929                                 Andorra     AND      AND
# 1024                                 Angola     AGO      ANG
# 930                     Antigua and Barbuda     ATG      ANT
# 16                                Argentina     ARG      ARG
# 1579                                Armenia     ARM      ARM
# 1249                                  Aruba     ABW      ARU
# 62                              Australasia     NaN      ANZ
# 0                                 Australia     AUS      AUS
# 1                                   Austria     AUT      AUT
# 1583                             Azerbaijan     AZE      AZE
# 378                                 Bahamas     BHS      BAH
# 1109                                Bahrain     BHR      BRN
# 1110                             Bangladesh     BGD      BAN
# 702                                Barbados     BRB      BAR
# 1588                                Belarus     BLR      BLR
# 19                                  Belgium     BEL      BEL
# 704                                  Belize     BLZ      BIZ
# 818                                   Benin     BEN      BEN
# 272                                 Bermuda     BMU      BER
# 1116                                 Bhutan     BTN      BHU
# 24                                  Bohemia     NaN      BOH
# 273                                 Bolivia     BOL      BOL
# 1422                 Bosnia and Herzegovina     BIH      BIH
# 1029                               Botswana     BWA      BOT
# 20                                   Brazil     BRA      BRA
# 1120                 British Virgin Islands     VGB      IVB
# 1265                                 Brunei     BRN      BRU
# 2                                  Bulgaria     BGR      BUL
# 823                            Burkina Faso     BFA      BUR
# 1602                                Burundi     BDI      BDI
# 453                                Cambodia     KHM      CAM
# 613                                Cameroon     CMR      CMR
# 21                                   Canada     CAN      CAN
# 1606                             Cape Verde     CPV      CPV
# 944                          Cayman Islands     CYM      CAY
# 711                Central African Republic     CAF      CAF
# 615                                    Chad     TCD      CHA
# 3                                     Chile     CHL      CHI
# 1128                         Chinese Taipei     TWN      TPE
# 22                                 Colombia     COL      COL
# 1614                                Comoros     COM      COM
# 1279                           Cook Islands     COK      COK
# 280                              Costa Rica     CRI      CRC
# 1442                                Croatia     HRV      CRO
# 23                                     Cuba     CUB      CUB
# 1037                                 Cyprus     CYP      CYP
# 1623                         Czech Republic     CZE      CZE
# 117                          Czechoslovakia     NaN      TCH
# 621                           Côte d'Ivoire     CIV      CIV
# 867   Democratic People's Republic of Korea     PRK      PRK
# 716        Democratic Republic of the Congo     COD      COD
# 4                                   Denmark     DNK      DEN
# 1136                               Djibouti     DJI      DJI
# 1626                               Dominica     DMA      DMA
# 625                      Dominican Republic     DOM      DOM
# 1948                             East Timor     TMP      TLS
# 151                                 Ecuador     ECU      ECU
# 5                                     Egypt     EGY      EGY
# 725                             El Salvador     SLV      ESA
# 1141                      Equatorial Guinea     GNQ      GEQ
# 1828                                Eritrea     ERI      ERI
# 120                                 Estonia     EST      EST
# 841                                Eswatini     SWZ      SWZ
# 462                                Ethiopia     ETH      ETH
# 731             Federal Republic of Germany     DEU      FRG
# 1887         Federated States of Micronesia     FSM      FSM
# 463                                    Fiji     FJI      FIJ
# 68                                  Finland     FIN      FIN
# 6                                    France     FRA      FRA
# 846                                   Gabon     GAB      GAB
# 1640                                Georgia     GEO      GEO
# 730    German Democratic Republic (Germany)     DDR      GDR
# 7                                   Germany     DEU      GER
# 466                                 Germany     DEU      EUA
# 394                                   Ghana     GHA      GHA
# 8                             Great Britain     GBR      GBR
# 9                                    Greece     GRC      GRE
# 1152                                Grenada     GRD      GRN
# 1303                                   Guam     GUM      GUM
# 397                               Guatemala     GTM      GUA
# 736                                  Guinea     GIN      GUI
# 1649                          Guinea-Bissau     GNB      GBS
# 335                                  Guyana     GUY      GUY
# 30                                    Haiti     HTI      HAI
# 738                                Honduras     HND      HON
# 399                        Hong Kong, China     HKG      HKG
# 10                                  Hungary     HUN      HUN
# 97                                  Iceland     ISL      ISL
# 1968           Independent Olympic Athletes     NaN      IOA
# 1539           Independent Olympic Athletes     NaN      IOP
# 32                                    India     IND      IND
# 403                               Indonesia     IDN      INA
# 340                                    Iraq     IRQ      IRQ
# 161                                 Ireland     IRL      IRL
# 33                 Islamic Republic of Iran     IRN      IRI
# 406                                  Israel     ISR      ISR
# 11                                    Italy     ITA      ITA
# 343                                 Jamaica     JAM      JAM
# 99                                    Japan     JPN      JPN
# 1058                                 Jordan     JOR      JOR
# 1666                             Kazakhstan     KAZ      KAZ
# 481                                   Kenya     KEN      KEN
# 2067                               Kiribati     KIR      KIR
# 2683                                 Kosovo     SRB      KOS
# 753                                  Kuwait     KWT      KUW
# 1671                             Kyrgyzstan     KGZ      KGZ
# 1061                                   Laos     LAO      LAO
# 164                                  Latvia     LVA      LAT
# 345                                 Lebanon     LBN      LIB
# 871                                 Lesotho     LSO      LES
# 483                                 Liberia     LBR      LBR
# 650                                   Libya     LBY      LBA
# 296                           Liechtenstein     LIE      LIE
# 165                               Lithuania     LTU      LTU
# 35                               Luxembourg     LUX      LUX
# 15                                      MIX     NaN      ZZX
# 653                              Madagascar     MDG      MAD
# 876                                  Malawi     MWI      MAW
# 654                                Malaysia     MYS      MAS
# 485                                Malaysia     MYS      MAL
# 1334                               Maldives     MDV      MDV
# 655                                    Mali     MLI      MLI
# 210                                   Malta     MLT      MLT
# 2288                       Marshall Islands     MHL      MHL
# 1182                             Mauritania     MRT      MTN
# 1183                              Mauritius     MUS      MRI
# 36                                   Mexico     MEX      MEX
# 129                                  Monaco     MCO      MON
# 658                                Mongolia     MNG      MGL
# 2296                             Montenegro     MNE      MNE
# 564                                 Morocco     MAR      MAR
# 1072                             Mozambique     MOZ      MOZ
# 351                                 Myanmar     MMR      MYA
# 1511                                Namibia     NAM      NAM
# 1697                                  Nauru     NRU      NRU
# 661                                   Nepal     NPL      NEP
# 37                              Netherlands     NLD      NED
# 418                    Netherlands Antilles     ANT      AHO
# 38                              New Zealand     NZL      NZL
# 770                               Nicaragua     NIC      NCA
# 665                                   Niger     NGA      NIG
# 420                                 Nigeria     NGA      NGR
# 486                            North Borneo     NaN      NBO
# 1705                        North Macedonia     MKD      MKD
# 1239                            North Yemen     NaN      YAR
# 39                                   Norway     NOR      NOR
# 1197                                   Oman     OMN      OMA
# 355                                Pakistan     PAK      PAK
# 1907                                  Palau     PLW      PLW
# 1709                              Palestine     PSE      PLE
# 216                                  Panama     PAN      PAN
# 995                        Papua New Guinea     PNG      PNG
# 776                                Paraguay     PRY      PAR
# 385              People's Republic of China     CHN      CHN
# 40                                     Peru     PER      PER
# 172                             Philippines     PHL      PHI
# 173                                  Poland     POL      POL
# 103                                Portugal     PRT      POR
# 361                             Puerto Rico     PRI      PUR
# 1206                                  Qatar     QAT      QAT
# 2944                                    ROC     MAR      ROC
# 2789                   Refugee Olympic Team     NaN      ROT
# 236                       Republic of China     CHN      ROC
# 344                       Republic of Korea     KOR      KOR
# 1690                    Republic of Moldova     MDA      MDA
# 619                   Republic of the Congo     COG      CGO
# 41                                  Romania     ROU      ROU
# 42                       Russian Federation     RUS      RU1
# 1720                     Russian Federation     RUS      RUS
# 1208                                 Rwanda     RWA      RWA
# 393                                    Saar     NaN      SAA
# 1722                  Saint Kitts and Nevis     KNA      SKN
# 1723                            Saint Lucia     LCA      LCA
# 1366       Saint Vincent and the Grenadines     VCT      VIN
# 1209                                  Samoa     WSM      SAM
# 580                              San Marino     SMR      SMR
# 904                            Saudi Arabia     SAU      KSA
# 677                                 Senegal     SEN      SEN
# 105                                  Serbia     SRB      SRB
# 1730                  Serbia and Montenegro     SCG      SCG
# 1088                             Seychelles     SYC      SEY
# 787                            Sierra Leone     SLE      SLE
# 363                               Singapore     SGP      SGP
# 1734                               Slovakia     SVK      SVK
# 1543                               Slovenia     SVN      SLO
# 1217                        Solomon Islands     SLB      SOL
# 908                                 Somalia     SOM      SOM
# 57                             South Africa     ZAF      RSA
# 2552                            South Sudan     SSD      SSD
# 1398                            South Yemen     NaN      YMD
# 429                            Soviet Union     SUN      URS
# 43                                    Spain     ESP      ESP
# 366                               Sri Lanka     LKA      SRI
# 586                                   Sudan     SDN      SUD
# 587                                Suriname     SUR      SUR
# 12                                   Sweden     SWE      SWE
# 13                              Switzerland     CHE      SUI
# 369                    Syrian Arab Republic     SYR      SYR
# 1727                  São Tomé and Príncipe     STP      STP
# 1746                             Tajikistan     TJK      TJK
# 437                                Thailand     THA      THA
# 1147                             The Gambia     GMB      GAM
# 918                                    Togo     TGO      TOG
# 1229                                  Tonga     TON      TGA
# 370                     Trinidad and Tobago     TTO      TTO
# 593                                 Tunisia     TUN      TUN
# 81                                   Turkey     TUR      TUR
# 1754                           Turkmenistan     TKM      TKM
# 2361                                 Tuvalu     TUV      TUV
# 511                                  Uganda     UGA      UGA
# 1756                                Ukraine     UKR      UKR
# 1532                           Unified Team     NaN      EUN
# 1234                   United Arab Emirates     ARE      UAE
# 684             United Republic of Tanzania     TZA      TAN
# 14                 United States of America     USA      USA
# 183                                 Uruguay     URY      URU
# 1760                             Uzbekistan     UZB      UZB
# 1394                                Vanuatu     VUT      VAN
# 374                               Venezuela     VEN      VEN
# 443                                 Vietnam     VNM      VIE
# 806                      Virgin Islands, US     VIR      ISV
# 592                  West Indies Federation     NaN      BWI
# 1568                                  Yemen     YEM      YEM
# 134                              Yugoslavia     YUG      YUG
# 694                                  Zambia     ZMB      ZAM
# 229                                Zimbabwe     ZWE      ZIM
#
#                                              google_iso
# 267      www.google.com/search?q=iso+alpha3+Afghanistan
# 809          www.google.com/search?q=iso+alpha3+Albania
# 602          www.google.com/search?q=iso+alpha3+Algeria
# 1244  www.google.com/search?q=iso+alpha3+American+Samoa
# 929          www.google.com/search?q=iso+alpha3+Andorra
# 1024          www.google.com/search?q=iso+alpha3+Angola
# 930   www.google.com/search?q=iso+alpha3+Antigua+and...
# 16         www.google.com/search?q=iso+alpha3+Argentina
# 1579         www.google.com/search?q=iso+alpha3+Armenia
# 1249           www.google.com/search?q=iso+alpha3+Aruba
# 62       www.google.com/search?q=iso+alpha3+Australasia
# 0          www.google.com/search?q=iso+alpha3+Australia
# 1            www.google.com/search?q=iso+alpha3+Austria
# 1583      www.google.com/search?q=iso+alpha3+Azerbaijan
# 378          www.google.com/search?q=iso+alpha3+Bahamas
# 1109         www.google.com/search?q=iso+alpha3+Bahrain
# 1110      www.google.com/search?q=iso+alpha3+Bangladesh
# 702         www.google.com/search?q=iso+alpha3+Barbados
# 1588         www.google.com/search?q=iso+alpha3+Belarus
# 19           www.google.com/search?q=iso+alpha3+Belgium
# 704           www.google.com/search?q=iso+alpha3+Belize
# 818            www.google.com/search?q=iso+alpha3+Benin
# 272          www.google.com/search?q=iso+alpha3+Bermuda
# 1116          www.google.com/search?q=iso+alpha3+Bhutan
# 24           www.google.com/search?q=iso+alpha3+Bohemia
# 273          www.google.com/search?q=iso+alpha3+Bolivia
# 1422  www.google.com/search?q=iso+alpha3+Bosnia+and+...
# 1029        www.google.com/search?q=iso+alpha3+Botswana
# 20            www.google.com/search?q=iso+alpha3+Brazil
# 1120  www.google.com/search?q=iso+alpha3+British+Vir...
# 1265          www.google.com/search?q=iso+alpha3+Brunei
# 2           www.google.com/search?q=iso+alpha3+Bulgaria
# 823     www.google.com/search?q=iso+alpha3+Burkina+Faso
# 1602         www.google.com/search?q=iso+alpha3+Burundi
# 453         www.google.com/search?q=iso+alpha3+Cambodia
# 613         www.google.com/search?q=iso+alpha3+Cameroon
# 21            www.google.com/search?q=iso+alpha3+Canada
# 1606      www.google.com/search?q=iso+alpha3+Cape+Verde
# 944   www.google.com/search?q=iso+alpha3+Cayman+Islands
# 711   www.google.com/search?q=iso+alpha3+Central+Afr...
# 615             www.google.com/search?q=iso+alpha3+Chad
# 3              www.google.com/search?q=iso+alpha3+Chile
# 1128  www.google.com/search?q=iso+alpha3+Chinese+Taipei
# 22          www.google.com/search?q=iso+alpha3+Colombia
# 1614         www.google.com/search?q=iso+alpha3+Comoros
# 1279    www.google.com/search?q=iso+alpha3+Cook+Islands
# 280       www.google.com/search?q=iso+alpha3+Costa+Rica
# 1442         www.google.com/search?q=iso+alpha3+Croatia
# 23              www.google.com/search?q=iso+alpha3+Cuba
# 1037          www.google.com/search?q=iso+alpha3+Cyprus
# 1623  www.google.com/search?q=iso+alpha3+Czech+Republic
# 117   www.google.com/search?q=iso+alpha3+Czechoslovakia
# 621    www.google.com/search?q=iso+alpha3+Côte+d'Ivoire
# 867   www.google.com/search?q=iso+alpha3+Democratic+...
# 716   www.google.com/search?q=iso+alpha3+Democratic+...
# 4            www.google.com/search?q=iso+alpha3+Denmark
# 1136        www.google.com/search?q=iso+alpha3+Djibouti
# 1626        www.google.com/search?q=iso+alpha3+Dominica
# 625   www.google.com/search?q=iso+alpha3+Dominican+R...
# 1948      www.google.com/search?q=iso+alpha3+East+Timor
# 151          www.google.com/search?q=iso+alpha3+Ecuador
# 5              www.google.com/search?q=iso+alpha3+Egypt
# 725      www.google.com/search?q=iso+alpha3+El+Salvador
# 1141  www.google.com/search?q=iso+alpha3+Equatorial+...
# 1828         www.google.com/search?q=iso+alpha3+Eritrea
# 120          www.google.com/search?q=iso+alpha3+Estonia
# 841         www.google.com/search?q=iso+alpha3+Eswatini
# 462         www.google.com/search?q=iso+alpha3+Ethiopia
# 731   www.google.com/search?q=iso+alpha3+Federal+Rep...
# 1887  www.google.com/search?q=iso+alpha3+Federated+S...
# 463             www.google.com/search?q=iso+alpha3+Fiji
# 68           www.google.com/search?q=iso+alpha3+Finland
# 6             www.google.com/search?q=iso+alpha3+France
# 846            www.google.com/search?q=iso+alpha3+Gabon
# 1640         www.google.com/search?q=iso+alpha3+Georgia
# 730   www.google.com/search?q=iso+alpha3+German+Demo...
# 7            www.google.com/search?q=iso+alpha3+Germany
# 466          www.google.com/search?q=iso+alpha3+Germany
# 394            www.google.com/search?q=iso+alpha3+Ghana
# 8      www.google.com/search?q=iso+alpha3+Great+Britain
# 9             www.google.com/search?q=iso+alpha3+Greece
# 1152         www.google.com/search?q=iso+alpha3+Grenada
# 1303            www.google.com/search?q=iso+alpha3+Guam
# 397        www.google.com/search?q=iso+alpha3+Guatemala
# 736           www.google.com/search?q=iso+alpha3+Guinea
# 1649   www.google.com/search?q=iso+alpha3+Guinea-Bissau
# 335           www.google.com/search?q=iso+alpha3+Guyana
# 30             www.google.com/search?q=iso+alpha3+Haiti
# 738         www.google.com/search?q=iso+alpha3+Honduras
# 399   www.google.com/search?q=iso+alpha3+Hong+Kong,+...
# 10           www.google.com/search?q=iso+alpha3+Hungary
# 97           www.google.com/search?q=iso+alpha3+Iceland
# 1968  www.google.com/search?q=iso+alpha3+Independent...
# 1539  www.google.com/search?q=iso+alpha3+Independent...
# 32             www.google.com/search?q=iso+alpha3+India
# 403        www.google.com/search?q=iso+alpha3+Indonesia
# 340             www.google.com/search?q=iso+alpha3+Iraq
# 161          www.google.com/search?q=iso+alpha3+Ireland
# 33    www.google.com/search?q=iso+alpha3+Islamic+Rep...
# 406           www.google.com/search?q=iso+alpha3+Israel
# 11             www.google.com/search?q=iso+alpha3+Italy
# 343          www.google.com/search?q=iso+alpha3+Jamaica
# 99             www.google.com/search?q=iso+alpha3+Japan
# 1058          www.google.com/search?q=iso+alpha3+Jordan
# 1666      www.google.com/search?q=iso+alpha3+Kazakhstan
# 481            www.google.com/search?q=iso+alpha3+Kenya
# 2067        www.google.com/search?q=iso+alpha3+Kiribati
# 2683          www.google.com/search?q=iso+alpha3+Kosovo
# 753           www.google.com/search?q=iso+alpha3+Kuwait
# 1671      www.google.com/search?q=iso+alpha3+Kyrgyzstan
# 1061            www.google.com/search?q=iso+alpha3+Laos
# 164           www.google.com/search?q=iso+alpha3+Latvia
# 345          www.google.com/search?q=iso+alpha3+Lebanon
# 871          www.google.com/search?q=iso+alpha3+Lesotho
# 483          www.google.com/search?q=iso+alpha3+Liberia
# 650            www.google.com/search?q=iso+alpha3+Libya
# 296    www.google.com/search?q=iso+alpha3+Liechtenstein
# 165        www.google.com/search?q=iso+alpha3+Lithuania
# 35        www.google.com/search?q=iso+alpha3+Luxembourg
# 15               www.google.com/search?q=iso+alpha3+MIX
# 653       www.google.com/search?q=iso+alpha3+Madagascar
# 876           www.google.com/search?q=iso+alpha3+Malawi
# 654         www.google.com/search?q=iso+alpha3+Malaysia
# 485         www.google.com/search?q=iso+alpha3+Malaysia
# 1334        www.google.com/search?q=iso+alpha3+Maldives
# 655             www.google.com/search?q=iso+alpha3+Mali
# 210            www.google.com/search?q=iso+alpha3+Malta
# 2288  www.google.com/search?q=iso+alpha3+Marshall+Is...
# 1182      www.google.com/search?q=iso+alpha3+Mauritania
# 1183       www.google.com/search?q=iso+alpha3+Mauritius
# 36            www.google.com/search?q=iso+alpha3+Mexico
# 129           www.google.com/search?q=iso+alpha3+Monaco
# 658         www.google.com/search?q=iso+alpha3+Mongolia
# 2296      www.google.com/search?q=iso+alpha3+Montenegro
# 564          www.google.com/search?q=iso+alpha3+Morocco
# 1072      www.google.com/search?q=iso+alpha3+Mozambique
# 351          www.google.com/search?q=iso+alpha3+Myanmar
# 1511         www.google.com/search?q=iso+alpha3+Namibia
# 1697           www.google.com/search?q=iso+alpha3+Nauru
# 661            www.google.com/search?q=iso+alpha3+Nepal
# 37       www.google.com/search?q=iso+alpha3+Netherlands
# 418   www.google.com/search?q=iso+alpha3+Netherlands...
# 38       www.google.com/search?q=iso+alpha3+New+Zealand
# 770        www.google.com/search?q=iso+alpha3+Nicaragua
# 665            www.google.com/search?q=iso+alpha3+Niger
# 420          www.google.com/search?q=iso+alpha3+Nigeria
# 486     www.google.com/search?q=iso+alpha3+North+Borneo
# 1705  www.google.com/search?q=iso+alpha3+North+Maced...
# 1239     www.google.com/search?q=iso+alpha3+North+Yemen
# 39            www.google.com/search?q=iso+alpha3+Norway
# 1197            www.google.com/search?q=iso+alpha3+Oman
# 355         www.google.com/search?q=iso+alpha3+Pakistan
# 1907           www.google.com/search?q=iso+alpha3+Palau
# 1709       www.google.com/search?q=iso+alpha3+Palestine
# 216           www.google.com/search?q=iso+alpha3+Panama
# 995   www.google.com/search?q=iso+alpha3+Papua+New+G...
# 776         www.google.com/search?q=iso+alpha3+Paraguay
# 385   www.google.com/search?q=iso+alpha3+People's+Re...
# 40              www.google.com/search?q=iso+alpha3+Peru
# 172      www.google.com/search?q=iso+alpha3+Philippines
# 173           www.google.com/search?q=iso+alpha3+Poland
# 103         www.google.com/search?q=iso+alpha3+Portugal
# 361      www.google.com/search?q=iso+alpha3+Puerto+Rico
# 1206           www.google.com/search?q=iso+alpha3+Qatar
# 2944             www.google.com/search?q=iso+alpha3+ROC
# 2789  www.google.com/search?q=iso+alpha3+Refugee+Oly...
# 236   www.google.com/search?q=iso+alpha3+Republic+of...
# 344   www.google.com/search?q=iso+alpha3+Republic+of...
# 1690  www.google.com/search?q=iso+alpha3+Republic+of...
# 619   www.google.com/search?q=iso+alpha3+Republic+of...
# 41           www.google.com/search?q=iso+alpha3+Romania
# 42    www.google.com/search?q=iso+alpha3+Russian+Fed...
# 1720  www.google.com/search?q=iso+alpha3+Russian+Fed...
# 1208          www.google.com/search?q=iso+alpha3+Rwanda
# 393             www.google.com/search?q=iso+alpha3+Saar
# 1722  www.google.com/search?q=iso+alpha3+Saint+Kitts...
# 1723     www.google.com/search?q=iso+alpha3+Saint+Lucia
# 1366  www.google.com/search?q=iso+alpha3+Saint+Vince...
# 1209           www.google.com/search?q=iso+alpha3+Samoa
# 580       www.google.com/search?q=iso+alpha3+San+Marino
# 904     www.google.com/search?q=iso+alpha3+Saudi+Arabia
# 677          www.google.com/search?q=iso+alpha3+Senegal
# 105           www.google.com/search?q=iso+alpha3+Serbia
# 1730  www.google.com/search?q=iso+alpha3+Serbia+and+...
# 1088      www.google.com/search?q=iso+alpha3+Seychelles
# 787     www.google.com/search?q=iso+alpha3+Sierra+Leone
# 363        www.google.com/search?q=iso+alpha3+Singapore
# 1734        www.google.com/search?q=iso+alpha3+Slovakia
# 1543        www.google.com/search?q=iso+alpha3+Slovenia
# 1217  www.google.com/search?q=iso+alpha3+Solomon+Isl...
# 908          www.google.com/search?q=iso+alpha3+Somalia
# 57      www.google.com/search?q=iso+alpha3+South+Africa
# 2552     www.google.com/search?q=iso+alpha3+South+Sudan
# 1398     www.google.com/search?q=iso+alpha3+South+Yemen
# 429     www.google.com/search?q=iso+alpha3+Soviet+Union
# 43             www.google.com/search?q=iso+alpha3+Spain
# 366        www.google.com/search?q=iso+alpha3+Sri+Lanka
# 586            www.google.com/search?q=iso+alpha3+Sudan
# 587         www.google.com/search?q=iso+alpha3+Suriname
# 12            www.google.com/search?q=iso+alpha3+Sweden
# 13       www.google.com/search?q=iso+alpha3+Switzerland
# 369   www.google.com/search?q=iso+alpha3+Syrian+Arab...
# 1727  www.google.com/search?q=iso+alpha3+São+Tomé+an...
# 1746      www.google.com/search?q=iso+alpha3+Tajikistan
# 437         www.google.com/search?q=iso+alpha3+Thailand
# 1147      www.google.com/search?q=iso+alpha3+The+Gambia
# 918             www.google.com/search?q=iso+alpha3+Togo
# 1229           www.google.com/search?q=iso+alpha3+Tonga
# 370   www.google.com/search?q=iso+alpha3+Trinidad+an...
# 593          www.google.com/search?q=iso+alpha3+Tunisia
# 81            www.google.com/search?q=iso+alpha3+Turkey
# 1754    www.google.com/search?q=iso+alpha3+Turkmenistan
# 2361          www.google.com/search?q=iso+alpha3+Tuvalu
# 511           www.google.com/search?q=iso+alpha3+Uganda
# 1756         www.google.com/search?q=iso+alpha3+Ukraine
# 1532    www.google.com/search?q=iso+alpha3+Unified+Team
# 1234  www.google.com/search?q=iso+alpha3+United+Arab...
# 684   www.google.com/search?q=iso+alpha3+United+Repu...
# 14    www.google.com/search?q=iso+alpha3+United+Stat...
# 183          www.google.com/search?q=iso+alpha3+Uruguay
# 1760      www.google.com/search?q=iso+alpha3+Uzbekistan
# 1394         www.google.com/search?q=iso+alpha3+Vanuatu
# 374        www.google.com/search?q=iso+alpha3+Venezuela
# 443          www.google.com/search?q=iso+alpha3+Vietnam
# 806   www.google.com/search?q=iso+alpha3+Virgin+Isla...
# 592   www.google.com/search?q=iso+alpha3+West+Indies...
# 1568           www.google.com/search?q=iso+alpha3+Yemen
# 134       www.google.com/search?q=iso+alpha3+Yugoslavia
# 694           www.google.com/search?q=iso+alpha3+Zambia
# 229         www.google.com/search?q=iso+alpha3+Zimbabwe

# %%
iso_corrections = {'Czechoslovakia': 'CSK', # correction
                   'ROC': 'RUS', # assume ROC is Russia
                   'Kosovo': 'XXK', # corrected from Serbia SRB
                   'Niger': 'NER'} # corrected from Nigeria NGA
for country in iso_corrections:
    results_f.loc[results_f.country==country, 'alpha_3'] = iso_corrections[country]
results_f[results_f.country.isin(iso_corrections.keys())].drop_duplicates('country').head()
# Out:
#              games         country alpha_3 ioc_code  host  year  gold  silver  \
# 117   Antwerp 1920  Czechoslovakia     CSK      TCH     0  1920     0       0
# 665     Tokyo 1964           Niger     NER      NIG     0  1964     0       0
# 2683      Rio 2016          Kosovo     XXK      KOS     0  2016     1       0
# 2944    Tokyo 2020             ROC     RUS      ROC     0  2021    20      28
#
#       bronze  total  summer  associate_nations
# 117        2      2       1                NaN
# 665        0      0       1                NaN
# 2683       0      1       1                NaN
# 2944      23     71       1                NaN

# %%
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')

# %% [markdown]
# ## Historic population by country (different times ahead of games)
# Difficult to know how soon population impacts olympic success. Will generate features for year -0, -4, -8, -12, -16, -20,  -24, -28, -32, -36, -40.

# %%
# load data
population_fname2 = r'maddison_population.csv'
population = pd.read_csv(os.path.join(project_path, population_fname2))

# extract country codes from top row (rename, convert to dataframe) and set headers
country_codes = population.iloc[0,1:].rename('alpha_3').to_frame()
population = population.rename(columns={'Population': 'year'})
population = population.iloc[1:]

#unpivot data, drop blank rows, convert year and population to numeric types
population = pd.melt(population, id_vars=['year'],
                     value_vars=population.columns[1:],
                     var_name='country',
                     value_name='population')
population.dropna(axis=0, inplace=True)
population = population.sort_values(['country', 'year'])
population['year'] = population.year.astype('int')
population['population'] = population.population.str.replace(',', '').astype('float')

# join country codes back onto data & reorder cols
population = population.merge(country_codes,
                              how='left',
                              left_on='country',
                              right_index=True)
population = population[['country', 'alpha_3', 'year', 'population']]

print('max year: {}'.format(population.year.max()))
population.head()
# Out:
# max year: 2018
#          country alpha_3  year  population
# 573  Afghanistan     AFG  1820      3280.0
# 623  Afghanistan     AFG  1870      4207.0
# 666  Afghanistan     AFG  1913      5730.0
# 703  Afghanistan     AFG  1950      8150.0
# 704  Afghanistan     AFG  1951      8284.0

# %%
pop_trans_fname = r'population_transformed.csv'
population.to_csv(os.path.join(project_path, pop_trans_fname), index=False)

# %% [markdown]
# Now we have population data for up to 2018.

# %% [markdown]
# ### Interpolating population onto games

# %%
year_deltas = list(range(0, 44, 4))

for yd in tqdm(year_deltas):
    results_f[f'pop_{yd}'] = results_f.apply(lambda row: historical_interp(country_code=row.alpha_3,
                                                                           year=row.year - yd,
                                                                           df_lookup=population,
                                                                           x_col='year',
                                                                           y_col='population',
                                                                           country_code_col='alpha_3'), axis=1)

results_f.head()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 11/11 [02:22<00:00, 12.96s/it]
#          games    country alpha_3 ioc_code  host  year  gold  silver  bronze  \
# 0  Athens 1896  Australia     AUS      AUS     0  1896     2       0       0
# 1  Athens 1896    Austria     AUT      AUT     0  1896     2       1       2
# 2  Athens 1896   Bulgaria     BGR      BUL     0  1896     0       0       0
# 3  Athens 1896      Chile     CHL      CHI     0  1896     0       0       0
# 4  Athens 1896    Denmark     DNK      DEN     0  1896     1       2       3
#
#    total  ...   pop_4   pop_8  pop_12  pop_16  pop_20  pop_24  pop_28  pop_32  \
# 0      2  ...  3274.0  2932.0  2556.0  2197.0  1929.0  1722.0  1700.0  1495.0
# 1      5  ...  5504.0  5303.0  5121.0  4941.0  4772.0  4604.0  4469.0  4350.0
# 2      0  ...  3556.0  3359.1  3187.3  3015.5  2843.7  2671.9  2577.4  2560.2
# 3      0  ...  2678.0  2538.0  2400.0  2264.0  2132.0  2006.0  1885.0  1770.0
# 4      6  ...  2327.0  2257.0  2160.0  2081.0  1994.0  1918.0  1852.0  1777.0
#
#    pop_36  pop_40
# 0  1326.0  1065.0
# 1  4235.0  4120.0
# 2  2543.0  2525.8
# 3  1661.0  1557.0
# 4  1696.0  1612.0
#
# [5 rows x 23 columns]

# %%
results_f[(results_f.alpha_3=='PAK') & results_f.pop_0.isna()]
# Out:
#             games   country alpha_3 ioc_code  host  year  gold  silver  \
# 355   London 1948  Pakistan     PAK      PAK     0  1948     0       0
# 2931   Tokyo 2020  Pakistan     PAK      PAK     0  2021     0       0
#
#       bronze  total  ...     pop_4     pop_8    pop_12    pop_16    pop_20  \
# 355        0      0  ...       NaN       NaN       NaN       NaN       NaN
# 2931       0      0  ...  215301.0  197992.0  180688.0  165075.0  150448.0
#
#         pop_24    pop_28    pop_32   pop_36   pop_40
# 355        NaN       NaN       NaN      NaN      NaN
# 2931  134717.0  122052.0  111528.0  99076.0  88417.0
#
# [2 rows x 23 columns]

# %%
results_f.isna().sum() / results_f.shape[0] * 100
# Out:
# games                  0.000000
# country                0.000000
# alpha_3                0.700935
# ioc_code               0.000000
# host                   0.000000
# year                   0.000000
# gold                   0.000000
# silver                 0.000000
# bronze                 0.000000
# total                  0.000000
# summer                 0.000000
# associate_nations    100.000000
# pop_0                 21.428571
# pop_4                 16.088117
# pop_8                 16.355140
# pop_12                16.688919
# pop_16                17.323097
# pop_20                18.090788
# pop_24                19.025367
# pop_28                19.359146
# pop_32                20.126836
# pop_36                21.628838
# pop_40                23.164219
# dtype: float64

# %% [markdown]
# ~20% of population values haven't interpolated. Worth investigating why this is (e.g. Andorra seems to be a complete miss--is it not in the population data?)
#
# Likely because some codes are missing and others have dates that start in mid-1900s for example.
#
# Remember there is no population data beyond 2018, so no values will be interpolated onto Tokyo 2020

# %%
results_f.loc[results_f.pop_4.isna(), 'country'].sort_values().unique()
# Out:
# array(['American Samoa', 'Andorra', 'Antigua and Barbuda', 'Aruba',
#        'Australasia', 'Bahamas', 'Belize', 'Bermuda', 'Bhutan', 'Bohemia',
#        'British Virgin Islands', 'Brunei', 'Cayman Islands',
#        'Cook Islands', 'East Timor', 'Eritrea', 'Estonia',
#        'Federated States of Micronesia', 'Fiji',
#        'German Democratic Republic (Germany)', 'Grenada', 'Guam',
#        'Guyana', 'Iceland', 'Independent Olympic Athletes', 'Israel',
#        'Kiribati', 'Kosovo', 'Latvia', 'Liechtenstein', 'Lithuania',
#        'Luxembourg', 'MIX', 'Maldives', 'Malta', 'Marshall Islands',
#        'Monaco', 'Nauru', 'Netherlands Antilles', 'Nigeria',
#        'North Borneo', 'North Yemen', 'Pakistan', 'Palau',
#        'Papua New Guinea', 'Refugee Olympic Team', 'Russian Federation',
#        'Saar', 'Saint Kitts and Nevis',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Serbia', 'Serbia and Montenegro', 'Solomon Islands', 'Somalia',
#        'South Sudan', 'South Yemen', 'Suriname', 'Tonga', 'Tuvalu',
#        'Unified Team', 'Vanuatu', 'Virgin Islands, US',
#        'West Indies Federation', 'Zimbabwe'], dtype=object)

# %% [markdown]
# ## Historic GDP per capita by country
# Expect best feature to be 4yrs prior (start of cycle), but will generate 0, -4, -8, -12

# %%
gdp_fname = r'gdp-per-capita-maddison-2020.csv'
gdp = pd.read_csv(os.path.join(project_path, gdp_fname))

col_renames = {'Entity': 'country', 'Code': 'alpha_3', 'Year': 'year', 'GDP per capita': 'gdp_pc'}
gdp.rename(columns=col_renames, inplace=True)
               
gdp['year'] = gdp.year.astype('int')
               
print('max year: {}'.format(gdp.year.max()))
gdp.head()
# Out:
# max year: 2018
#        country alpha_3  year  gdp_pc 145446-annotations
# 0  Afghanistan     AFG  1950  1156.0                NaN
# 1  Afghanistan     AFG  1951  1170.0                NaN
# 2  Afghanistan     AFG  1952  1189.0                NaN
# 3  Afghanistan     AFG  1953  1240.0                NaN
# 4  Afghanistan     AFG  1954  1245.0                NaN

# %% [markdown]
# GDPpc data goes up to 2018, which should be good enough (and as good as can get).

# %% [markdown]
# ### Inerpolating GDP per capita onto games

# %%
year_deltas = list(range(0, 44, 4))

for yd in tqdm(year_deltas):
    results_f[f'gdppc_{yd}'] = results_f.apply(lambda row: historical_interp(country_code=row.alpha_3,
                                                                           year=row.year - yd,
                                                                           df_lookup=gdp,
                                                                           x_col='year',
                                                                           y_col='gdp_pc',
                                                                           country_code_col='alpha_3'), axis=1)

results_f.head()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 11/11 [02:58<00:00, 16.26s/it]
#          games    country alpha_3 ioc_code  host  year  gold  silver  bronze  \
# 0  Athens 1896  Australia     AUS      AUS     0  1896     2       0       0
# 1  Athens 1896    Austria     AUT      AUT     0  1896     2       1       2
# 2  Athens 1896   Bulgaria     BGR      BUL     0  1896     0       0       0
# 3  Athens 1896      Chile     CHL      CHI     0  1896     0       0       0
# 4  Athens 1896    Denmark     DNK      DEN     0  1896     1       2       3
#
#    total  ...  gdppc_4      gdppc_8     gdppc_12     gdppc_16     gdppc_20  \
# 0      2  ...   6368.0  7179.000000  6861.000000  6830.000000  6387.000000
# 1      5  ...   4041.0  3792.000000  3583.000000  3314.000000  3188.000000
# 2      0  ...   1804.0  1719.454545  1634.909091  1550.363636  1465.818182
# 3      0  ...   3005.0  2617.000000  2703.000000  2418.000000  1988.000000
# 4      6  ...   4141.0  3808.000000  3642.000000  3476.000000  3395.000000
#
#       gdppc_24  gdppc_28  gdppc_32  gdppc_36  gdppc_40
# 0  5663.000000    5031.0    4616.0    4613.0    4866.0
# 1  3150.000000    2942.8    2888.4    2834.0    2752.4
# 2  1381.272727       NaN       NaN       NaN       NaN
# 3  1910.000000    1714.0    1667.0    1588.0    1427.0
# 4  3327.000000    2954.0    2922.0    2775.0    2735.0
#
# [5 rows x 34 columns]

# %%
results_f.isna().sum() / results_f.shape[0] * 100
# Out:
# games                  0.000000
# country                0.000000
# alpha_3                0.700935
# ioc_code               0.000000
# host                   0.000000
# year                   0.000000
# gold                   0.000000
# silver                 0.000000
# bronze                 0.000000
# total                  0.000000
# summer                 0.000000
# associate_nations    100.000000
# pop_0                 21.428571
# pop_4                 16.088117
# pop_8                 16.355140
# pop_12                16.688919
# pop_16                17.323097
# pop_20                18.090788
# pop_24                19.025367
# pop_28                19.359146
# pop_32                20.126836
# pop_36                21.628838
# pop_40                23.164219
# gdppc_0               22.897196
# gdppc_4               17.590120
# gdppc_8               17.990654
# gdppc_12              18.457944
# gdppc_16              19.359146
# gdppc_20              20.460614
# gdppc_24              22.096128
# gdppc_28              23.064085
# gdppc_32              24.732977
# gdppc_36              26.935915
# gdppc_40              29.372497
# dtype: float64

# %% [markdown]
# Similar numbers (~20%) of NaNs as with population. Investigate where they are in EDA.

# %% [markdown]
# ## Home Games
# Home games are already flagged in the data at this stage (from the Wikipedia participation data). Hypotheses are:
# 1. Having a future games awareded may raise performance in games prior. Recently they have been awarded 7 years in advance, so only one cycle ahead of the games would see a difference
# 2. A country may continue to perform highly after hosting due to effects of investment etc. Assume up to +3 cycles initially (can look to more)
#
# -1, +1, +2, +3 cycles

# %%
results_f[results_f.host==1].head(3)
# Out:
#              games                   country alpha_3 ioc_code  host  year  \
# 9      Athens 1896                    Greece     GRC      GRE     1  1896
# 26      Paris 1900                    France     FRA      FRA     1  1900
# 59  St. Louis 1904  United States of America     USA      USA     1  1904
#
#     gold  silver  bronze  total  ...  gdppc_4  gdppc_8  gdppc_12  gdppc_16  \
# 9     10      18      19     47  ...  2053.00  2566.00   2351.00   2028.00
# 26    27      38      37    102  ...  4280.00  3974.00   3617.00   3591.00
# 59    78      82      79    239  ...  8037.57  6885.67   7324.06   6447.28
#
#     gdppc_20  gdppc_24  gdppc_28  gdppc_32  gdppc_36  gdppc_40
# 9    1921.00   1806.00   2020.00   1854.00   2125.00   1757.00
# 26   3379.00   3233.00   3312.00   3159.00   3169.00   3016.00
# 59   6523.13   6255.73   5049.84   4991.98   4815.86   4889.14
#
# [3 rows x 34 columns]

# %%
def home_advantage(df_in, relative_games=[-1, 0, 1, 2, 3]):
    '''Function that adds columns of flags for whether countries are due to host games in the futures or have hosted games in the past.
    
    Args:
        df_in: The full pandas dataframe to insert the outputs to
        relative_games (optional): the relative games-cycles to a hosting year. For example, -1 would flag 1 for hosting year - 4 (i.e. the prior Olympics)
        
    Returns:
        A pandas dataframe with columns appended for each value in the relative games list. Naming uses "n" for prior cycles and "p" for future ones. Cycles are converted to years.
        
        For example, -1 would be host_n4, and 3 would be host_p12'''
    
    # copy df to output
    df = df_in.copy()
    
    # get list of hosts to iterate through
    hosts = df[df.host==1].copy()
    
    for i, row in hosts.iterrows():
        
        # filter temp dataframe for current host and extract year of hosting
        df_host = df[df.alpha_3==row['alpha_3']]
        yr = row['year']
        
        # iterate through relative games
        for rg in relative_games:
            # convert to years
            rg *= 4
            
            # set column prefixes
            if rg < 0:
                prefix = 'n'
            elif rg > 0:
                prefix = 'p'
            else:
                prefix = ''
            
            # generate column name and add to df if doesn't exist
            col = f'host_{prefix}{abs(rg)}'
            if col not in df.columns:
                df[col] = 0
            
            # get df index for relative year
            relative_yr = yr + rg
            if df_host[df_host.year==relative_yr].shape[0] != 0:
                idx = df_host[df_host.year==relative_yr].index[0]
                df.loc[idx, col] = 1
            
    return df

# %%
results_f = home_advantage(df_in=results_f, relative_games=[-1, 0, 1, 2, 3])
results_f[(results_f.alpha_3=='CHN') & (results_f.year>2000)]
# Out:
#              games                     country alpha_3 ioc_code  host  year  \
# 2009   Athens 2004  People's Republic of China     CHN      CHN     0  2004
# 2210  Beijing 2008  People's Republic of China     CHN      CHN     1  2008
# 2415   London 2012  People's Republic of China     CHN      CHN     0  2012
# 2622      Rio 2016  People's Republic of China     CHN      CHN     0  2016
# 2830    Tokyo 2020  People's Republic of China     CHN      CHN     0  2021
#
#       gold  silver  bronze  total  ...  gdppc_24  gdppc_28  gdppc_32  \
# 2009    32      17      14     63  ...   1930.00   1519.00    1431.0
# 2210    48      22      30    100  ...   2444.00   1930.00    1519.0
# 2415    38      31      22     91  ...   3045.00   2444.00    1930.0
# 2622    26      18      26     70  ...   3227.74   3045.00    2444.0
# 2830    38      32      18     88  ...   4310.83   3506.48    3022.0
#
#       gdppc_36  gdppc_40  host_n4  host_0  host_p4  host_p8  host_p12
# 2009    1178.0    1152.0        1       0        0        0         0
# 2210    1431.0    1178.0        0       1        0        0         0
# 2415    1519.0    1431.0        0       0        1        0         0
# 2622    1930.0    1519.0        0       0        0        1         0
# 2830    2619.0    1962.0        0       0        0        0         0
#
# [5 rows x 39 columns]

# %%
results_f.isna().sum() / results_f.shape[0] * 100
# Out:
# games                  0.000000
# country                0.000000
# alpha_3                0.700935
# ioc_code               0.000000
# host                   0.000000
# year                   0.000000
# gold                   0.000000
# silver                 0.000000
# bronze                 0.000000
# total                  0.000000
# summer                 0.000000
# associate_nations    100.000000
# pop_0                 21.428571
# pop_4                 16.088117
# pop_8                 16.355140
# pop_12                16.688919
# pop_16                17.323097
# pop_20                18.090788
# pop_24                19.025367
# pop_28                19.359146
# pop_32                20.126836
# pop_36                21.628838
# pop_40                23.164219
# gdppc_0               22.897196
# gdppc_4               17.590120
# gdppc_8               17.990654
# gdppc_12              18.457944
# gdppc_16              19.359146
# gdppc_20              20.460614
# gdppc_24              22.096128
# gdppc_28              23.064085
# gdppc_32              24.732977
# gdppc_36              26.935915
# gdppc_40              29.372497
# host_n4                0.000000
# host_0                 0.000000
# host_p4                0.000000
# host_p8                0.000000
# host_p12               0.000000
# dtype: float64

# %% [markdown]
# ## Medals Per Team
# Hypothesis: the number of medals won is a function of medals available per team participating.

# %%
results_f[results_f.year==1912].shape
# Out:
# (28, 39)

# %%
games_group = results_f.groupby('games')
games = games_group[['year']].first()
games['games_gold'] = games_group['gold'].sum()
games['games_silver'] = games_group['silver'].sum()
games['games_bronze'] = games_group['bronze'].sum()
games['games_medals'] = games_group['total'].sum()
games['n_teams'] = games_group['total'].count()
games['medals_per_team'] = games.games_medals / games.n_teams
games = games.sort_values('year').reset_index()
games.head()
# Out:
#             games  year  games_gold  games_silver  games_bronze  games_medals  \
# 0     Athens 1896  1896          43            43            36           122
# 1      Paris 1900  1900          96            95            93           284
# 2  St. Louis 1904  1904          97            96            93           286
# 3     London 1908  1908         110           107           107           324
# 4  Stockholm 1912  1912         108           105           104           317
#
#    n_teams  medals_per_team
# 0       16         7.625000
# 1       32         8.875000
# 2       13        22.000000
# 3       22        14.727273
# 4       28        11.321429

# %%
results_f[results_f.year==1896].sort_values('country')
# Out:
#           games                   country alpha_3 ioc_code  host  year  gold  \
# 0   Athens 1896                 Australia     AUS      AUS     0  1896     2
# 1   Athens 1896                   Austria     AUT      AUT     0  1896     2
# 2   Athens 1896                  Bulgaria     BGR      BUL     0  1896     0
# 3   Athens 1896                     Chile     CHL      CHI     0  1896     0
# 4   Athens 1896                   Denmark     DNK      DEN     0  1896     1
# 5   Athens 1896                     Egypt     EGY      EGY     0  1896     0
# 6   Athens 1896                    France     FRA      FRA     0  1896     5
# 7   Athens 1896                   Germany     DEU      GER     0  1896     6
# 8   Athens 1896             Great Britain     GBR      GBR     0  1896     2
# 9   Athens 1896                    Greece     GRC      GRE     1  1896    10
# 10  Athens 1896                   Hungary     HUN      HUN     0  1896     2
# 11  Athens 1896                     Italy     ITA      ITA     0  1896     0
# 15  Athens 1896                       MIX     NaN      ZZX     0  1896     1
# 12  Athens 1896                    Sweden     SWE      SWE     0  1896     0
# 13  Athens 1896               Switzerland     CHE      SUI     0  1896     1
# 14  Athens 1896  United States of America     USA      USA     0  1896    11
#
#     silver  bronze  total  ...     gdppc_24  gdppc_28  gdppc_32  gdppc_36  \
# 0        0       0      2  ...  5663.000000   5031.00   4616.00   4613.00
# 1        1       2      5  ...  3150.000000   2942.80   2888.40   2834.00
# 2        0       0      0  ...  1381.272727       NaN       NaN       NaN
# 3        0       0      0  ...  1910.000000   1714.00   1667.00   1588.00
# 4        2       3      6  ...  3327.000000   2954.00   2922.00   2775.00
# 5        0       0      0  ...  1217.279070   1185.44   1166.32   1147.20
# 6        4       2     11  ...  3312.000000   3159.00   3169.00   3016.00
# 7        5       2     13  ...  3078.000000   2966.00   2837.00   2613.00
# 8        3       2      7  ...  5769.000000   5636.00   5255.00   5086.00
# 9       18      19     47  ...  1806.000000   2020.00   1854.00   2125.00
# 10       1       3      6  ...  1801.700000       NaN       NaN       NaN
# 11       0       0      0  ...  2593.000000   2626.67   2642.03   2572.91
# 15       0       1      2  ...          NaN       NaN       NaN       NaN
# 12       0       0      0  ...  2259.000000   1774.00   1919.00   1941.00
# 13       2       0      3  ...  3140.490000   3053.11   2807.79   2933.63
# 14       7       2     20  ...  4991.980000   4815.86   4889.14   4401.89
#
#     gdppc_40  host_n4  host_0  host_p4  host_p8  host_p12
# 0    4866.00        0       0        0        0         0
# 1    2752.40        0       0        0        0         0
# 2        NaN        0       0        0        0         0
# 3    1427.00        0       0        0        0         0
# 4    2735.00        0       0        0        0         0
# 5    1128.08        0       0        0        0         0
# 6    2687.00        1       0        0        0         0
# 7    2440.00        0       0        0        0         0
# 8    5013.00        0       0        0        0         0
# 9    1757.00        0       1        0        0         0
# 10       NaN        0       0        0        0         0
# 11   2380.90        0       0        0        0         0
# 15       NaN        0       0        0        0         0
# 12   1771.00        0       0        0        0         0
# 13   2419.27        0       0        0        0         0
# 14   4247.62        0       0        0        0         0
#
# [16 rows x 39 columns]

# %%
cols = ['games', 'games_gold', 'games_silver', 'games_bronze', 'games_medals', 'n_teams', 'medals_per_team']
results_f = results_f.merge(games[cols],
                            how='left',
                            left_on='games',
                            right_on='games')
results_f.head()
# Out:
#          games    country alpha_3 ioc_code  host  year  gold  silver  bronze  \
# 0  Athens 1896  Australia     AUS      AUS     0  1896     2       0       0
# 1  Athens 1896    Austria     AUT      AUT     0  1896     2       1       2
# 2  Athens 1896   Bulgaria     BGR      BUL     0  1896     0       0       0
# 3  Athens 1896      Chile     CHL      CHI     0  1896     0       0       0
# 4  Athens 1896    Denmark     DNK      DEN     0  1896     1       2       3
#
#    total  ...  host_0  host_p4  host_p8  host_p12  games_gold  games_silver  \
# 0      2  ...       0        0        0         0          43            43
# 1      5  ...       0        0        0         0          43            43
# 2      0  ...       0        0        0         0          43            43
# 3      0  ...       0        0        0         0          43            43
# 4      6  ...       0        0        0         0          43            43
#
#    games_bronze  games_medals  n_teams  medals_per_team
# 0            36           122       16            7.625
# 1            36           122       16            7.625
# 2            36           122       16            7.625
# 3            36           122       16            7.625
# 4            36           122       16            7.625
#
# [5 rows x 45 columns]

# %% [markdown]
# ## Medals won at previous games
# Total medals won at last x games. Store nan where a country hasn't attended a games.

# %%
def year_country_total(year, country, df):
    ''' Returns total value for a given year/country combination in df. If no year country match, returns nan.'''
    
    mask = (df.year==year) & (df.country==country)
    if df[mask].shape[0] != 0:
        return df.loc[mask, 'total'].iloc[0]
    else:
        return np.nan

    
def previous_games_medal_total(df, n_games):
    ''' Adds historic medal counts for countries from.
    
    ARGS:
        df: dataframe containing olympic results data. Must have country, year, total columns
        n_games: list of integers used to count back the number of four-year cycles
    
    RETURNS:
        Dataframe with column(s) added for each value in n_games'''
    
    df = df.copy()
    
    # add games name year col (required to account for Tokyo)
    games_name_year_col = 'games_name_year'
    df[games_name_year_col] = df.games.str[-4:].astype(int)
    
    # iterate through n_games
    for n in tqdm(n_games):
        feature_name = f'past_tot_{n}'
        df[feature_name] = df.apply(lambda row: year_country_total(year=row[games_name_year_col] - 4 * n, 
                                                                   country=row['country'], 
                                                                   df=df), axis=1)
    # drop games name year col
    df.drop(columns=[games_name_year_col], inplace=True)
    return df

# %%
year_country_total(2016, 'Great Britain', results_f)
# Out:
# 67

# %%
results_f = previous_games_medal_total(results_f, [1, 2, 3, 4, 5])
results_f[results_f.country=='Great Britain'].head()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:30<00:00,  6.04s/it]
#              games        country alpha_3 ioc_code  host  year  gold  silver  \
# 8      Athens 1896  Great Britain     GBR      GBR     0  1896     2       3
# 28      Paris 1900  Great Britain     GBR      GBR     0  1900    15       8
# 54  St. Louis 1904  Great Britain     GBR      GBR     0  1904     1       1
# 71     London 1908  Great Britain     GBR      GBR     1  1908    56      51
# 94  Stockholm 1912  Great Britain     GBR      GBR     0  1912    10      15
#
#     bronze  total  ...  games_silver  games_bronze  games_medals  n_teams  \
# 8        2      7  ...            43            36           122       16
# 28       9     32  ...            95            93           284       32
# 54       0      2  ...            96            93           286       13
# 71      39    146  ...           107           107           324       22
# 94      16     41  ...           105           104           317       28
#
#     medals_per_team  past_tot_1  past_tot_2  past_tot_3  past_tot_4  \
# 8          7.625000         NaN         NaN         NaN         NaN
# 28         8.875000         7.0         NaN         NaN         NaN
# 54        22.000000        32.0         7.0         NaN         NaN
# 71        14.727273         2.0        32.0         7.0         NaN
# 94        11.321429       146.0         2.0        32.0         7.0
#
#     past_tot_5
# 8          NaN
# 28         NaN
# 54         NaN
# 71         NaN
# 94         NaN
#
# [5 rows x 50 columns]

# %%
results_f.head()
# Out:
#          games    country alpha_3 ioc_code  host  year  gold  silver  bronze  \
# 0  Athens 1896  Australia     AUS      AUS     0  1896     2       0       0
# 1  Athens 1896    Austria     AUT      AUT     0  1896     2       1       2
# 2  Athens 1896   Bulgaria     BGR      BUL     0  1896     0       0       0
# 3  Athens 1896      Chile     CHL      CHI     0  1896     0       0       0
# 4  Athens 1896    Denmark     DNK      DEN     0  1896     1       2       3
#
#    total  ...  games_silver  games_bronze  games_medals  n_teams  \
# 0      2  ...            43            36           122       16
# 1      5  ...            43            36           122       16
# 2      0  ...            43            36           122       16
# 3      0  ...            43            36           122       16
# 4      6  ...            43            36           122       16
#
#    medals_per_team  past_tot_1  past_tot_2  past_tot_3  past_tot_4  past_tot_5
# 0            7.625         NaN         NaN         NaN         NaN         NaN
# 1            7.625         NaN         NaN         NaN         NaN         NaN
# 2            7.625         NaN         NaN         NaN         NaN         NaN
# 3            7.625         NaN         NaN         NaN         NaN         NaN
# 4            7.625         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Save results with features

# %%
results_f = results_f.drop(columns=['associate_nations'])
results_f.head()
# Out:
#          games    country alpha_3 ioc_code  host  year  gold  silver  bronze  \
# 0  Athens 1896  Australia     AUS      AUS     0  1896     2       0       0
# 1  Athens 1896    Austria     AUT      AUT     0  1896     2       1       2
# 2  Athens 1896   Bulgaria     BGR      BUL     0  1896     0       0       0
# 3  Athens 1896      Chile     CHL      CHI     0  1896     0       0       0
# 4  Athens 1896    Denmark     DNK      DEN     0  1896     1       2       3
#
#    total  ...  games_silver  games_bronze  games_medals  n_teams  \
# 0      2  ...            43            36           122       16
# 1      5  ...            43            36           122       16
# 2      0  ...            43            36           122       16
# 3      0  ...            43            36           122       16
# 4      6  ...            43            36           122       16
#
#    medals_per_team  past_tot_1  past_tot_2  past_tot_3  past_tot_4  past_tot_5
# 0            7.625         NaN         NaN         NaN         NaN         NaN
# 1            7.625         NaN         NaN         NaN         NaN         NaN
# 2            7.625         NaN         NaN         NaN         NaN         NaN
# 3            7.625         NaN         NaN         NaN         NaN         NaN
# 4            7.625         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 49 columns]

# %%
olympics_data_fname = r'olympics_summer_features.csv'
results_f.to_csv(os.path.join(project_path, olympics_data_fname), index=False)
